# %% [markdown]
# <a href="https://colab.research.google.com/github/gustavolq/Imersao-Dados-Alura/blob/main/Aulas/Aulas_GustavoQuadra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 01
#
# Seja bem-vinda  ou bem-vindo ao notebook da aula 01, nesta aula vamos realizar nossa primeira análise de dados e no final já seremos capazes de tirar algumas conclusões.
#
# Nós desenvolveremos nosso projeto aqui no google colaboratory, assim podemos mesclar células contendo textos em formato markdown e células de código, além disso você não precisa instalar nada na sua máquina. Então, que tal começar testando algumas linhas de código?
#
# No campo abaixo temos o que chamamos de célula. Na célula nós podemos digitar textos, cálculos e códigos.
#
# Após eu introduzir o que eu quero na célula eu vou rodar esse conteúdo. Para isso podemos usar o atalho SHIFT + ENTER, ou até mesmo clicar no símbolo de play no canto esquerdo da célula. Na primeira vez que rodamos algo no nosso notebook ele vai demorar um pouco mais de tempo, e isso ocorre porque o google está alocando uma máquina virtual para nós utilizarmos.
#
# Vamos então fazer alguns testes, como os exemplos abaixo:

# %%
10 + 10
# Out:
# 20

# %%
'Thiago'
# Out:
# 'Thiago'

# %% [markdown]
# ### Importando os Dados
#
# Nessa imersão nós vamos mergulhar no universo da biologia e da biotecnologia e explorar uma base de dados da área.
#
# Para a nossa análise, está faltando então os dados. Para conseguirmos esses dados vamos acessar o Github, nesse link:
#
# https://github.com/alura-cursos/imersaodados3/tree/main/dados
#
# Os dados do GitHub são de culturas celulares.
#
# Então, agora vamos importar essa base de dados para dentro do nosso notebook. Para juntar essas informações vamos utilizar nossa famosa biblioteca do "Pandas".
# Vamos importar essa biblioteca através do seguinte código:

# %%
import pandas as pd
url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

dados = pd.read_csv(url_dados, compression = 'zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados.columns
# Out:
# Index(['id', 'tratamento', 'tempo', 'dose', 'droga', 'g-0', 'g-1', 'g-2',
#        'g-3', 'g-4',
#        ...
#        'c-90', 'c-91', 'c-92', 'c-93', 'c-94', 'c-95', 'c-96', 'c-97', 'c-98',
#        'c-99'],
#       dtype='object', length=877)

# %% [markdown]
# Observe que imprimimos agora todas as nossas linhas e colunas da nossa tabela.
#
# Aqui observamos que temos dados referentes a ID, tratamento, tempo, dose, entre outras.
#
# Para nos auxiliar na visualização e na identificação das colunas dos dados que vamos trabalhar, faremos um recorte, uma espécie de cabeçalho, com 5 linhas, e para isso usamos o seguinte comando:

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# Quando estávamos trabalhando com o conjunto total de dados nós tínhamos a informação do número total de linhas e colunas. Porém, agora com o head, nós perdemos essa informação. Então, caso você queira recuperar a informação do total de linhas e colunas basta utilizar:

# %%
dados.shape
# Out:
# (23814, 877)

# %% [markdown]
# Então, agora vamos voltar para o nosso problema.
#
# Nós queremos iniciar fazendo uma análise dos dados que estamos tratando. Vamos começar selecionando só uma coluna, para entendermos do que ela está tratando.
#
# Vamos iniciar com a coluna tratamento. Para isso vamos digitar:

# %%
dados['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %% [markdown]
# Esse tipo de informação, da coluna, é o que chamamos de 'série'. Já a tabela inteira nós chamos de 'dataframe'.
#
# Agora para vermos os tipos específicos de informação que temos dentro dessa coluna vamos digitar:

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %% [markdown]
# A resposta foi dada no formato de array, que nada mais é do que um vetor, ou seja, um tipo de estrutura de dados.
#
# Observe que encontramos dois tipos: 'com droga' e 'com controle'.
#
# Com droga, como o próprio nome nos diz, é quando estamos aplicando algum tipo de droga para a amostra. Já com o controle é uma técnica estatística em que isolamos as outras varíaveis e observamos apenas a variável de interesse.

# %% [markdown]
# Agora vamos analisar a coluna do tempo:

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %% [markdown]
# Encontramos 3 tipos de informação nessa coluna: 24, 72 e 48. O que pode nos indicar o tempo, provavelmente em horas, de intervalo que foi administrada a dose de medicamentos ou drogas.
#
# É interessante que observamos o comportamento das células com essa diferença de tempo, já que se analisássemos num período diferente poderia não dar tempo suficiente pra célula manifestar o determinado comportamento.

# %% [markdown]
# Além do tempo, podemos analisar também a coluna de dose:

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %% [markdown]
# Aqui obtemos dois tipos de doses diferentes, d1 e d2, mas não conseguimos afirmar nada categoricamente de antemão.

# %% [markdown]
# Vamos então analisar a categoria droga:

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %% [markdown]
# Agora com a resposta de ```dados['droga'].unique()``` obtivemos essa série de códigos como resposta. Talvez esses números foram codificados na tentativa de anonimizar os tipos de drogas usadas, para tentar evitar qualquer tipo de viés na análise dos resultados.
#
# Há uma série de regras quando alguns experimentos são feitos, evitando mostrar dados como nome, sexo, e outros fatores, dependendo da análise a ser feita, para que sejam evitados vieses.

# %% [markdown]
# Vamos analisar a coluna nomeada como g-0 agora:

# %%
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %% [markdown]
# Só olhando fica difícil tentar deduzir o que esses números representam. Então, nesse ponto, com o auxílio da Vanessa, especialista, conseguimos a informação que essa letra 'g' da coluna remete à palavra gene. Ou seja, esses números nos dizem a expressão de cada gene frente as drogas ou a exposição.
#
# Quando subimos de volta na tabela, percebemos que há diversos valores, inclusive com várias casas decimais. Aparentemente esses números foram "arredondados", normalizados, para podermos compará-los de alguma forma.
#
# Então, até agora na nossa análise, já conseguimos identificar e entender as informações de diferentes colunas; as colunas que nos indicam os tratamentos, as drogas, o tempo, e depois as respostas genéticas, que tem a letra g no ínicio do seu nome.
#
# Outro tipo de análise que podemos fazer agora é entender a distribuição dessas informações. Por exemplo, podemos saber quantos experimentos temos utilizando droga e quantos não utilizam; quantos usam o d1, e quantos utilizam o d2, e assim por diante.
#
# Como podemos fazer isso? Vamos utilizar esse código:

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %% [markdown]
# Agora, em vez de usarmos o ```.unique``` no código, nós utilizamos o ```.value_counts``` já que nosso objetivo era contar a quantidade de valores que apareciam nas colunas, nesse caso, na coluna ```tratamento```.
#
# No resultado ele retornou 2 linhas: uma com a quantidade de elementos que temos, ou seja, com a minha frequência, na categoria ```com_droga``` e a outra com a quantidade que temos na categoria ```com_controle```.
#
# Houve uma grande diferença no resultado dessas categorias, não é mesmo? Isso é, no mínimo, curioso. Então, Guilherme vai nos sugerir um desafio, de investigar o por quê dessa diferença tão grande.
#
# Nesse momento o Thiago já escreve outros dois desafios, o desafio #2 e o desafio #3. E a Vanessa também deixa o seu, desafio #4. Todos os desafios dessa aula estão escritos no final desse notebook.

# %% [markdown]
# Será que essa diferença entre os valores dentro das categorias continuam tão desproporcionais? Vamos investigar a categoria ```dose```:

# %%
dados['dose'].value_counts()
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %% [markdown]
# Nesse ponto parece que as coisas já estão mais equilibradas. Mas somente com o número é difícil fazermos uma leitura mais aprofundada. Então, nesse momento, vamos resolver um dos desafios deixados. Então, se até aqui você ainda nao resolveu os desafios do vídeo e nao quer receber um spoiler, pare aqui e tente resolvê-los primeiro.

# %% [markdown]
# Para entendermos melhor e fazer um comparativo é legal traçarmos a proporção entre os dados. Vamos escrever o código agora, setando como parâmetro, dentro dos parênteses o ```normalize = True``` :

# %%
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %% [markdown]
# Temos agora os dados "normalizados". Podemos interpretar utilizando a porcentagem (multiplicando por 100), o que nos daria algo em torno de 92% versus 8% (aproximadamente), mostrando o tamanho da desproporção.

# %% [markdown]
# Vamos fazer o mesmo agora com a coluna ```dose```:

# %%
dados['dose'].value_counts(normalize = True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %% [markdown]
# Temos aqui o resultado. Inclusive, como mini-desafio, você pode fazer o mesmo processo com as outras colunas.
#
# Certo, mas geralmente, quando há a trasmissão dessas informações, vemos uma série de gráficos. E, geralmente, é usado aquele gráfico que parece uma torta, ou uma pizza.
#
# Vamos então plotar um gráfico dessa tipo, com o seguinte código:

# %%
dados['tratamento'].value_counts().plot.pie()

# %% [markdown]
# Aqui, em azul, nós temos a quantidade de tratamento com drogas(que é muito maior, em proporção), e em laranja temos o tratamento "com controle". Ficou até parecendo um pacman, hehe.
#
# Vamos aproveitar e analisar as outras informações com os gráficos também, para vermos o que acontece. Vamos analisar a coluna tempo:

# %%
dados['tempo'].value_counts().plot.pie()

# %% [markdown]
# Repare como ficou difícil a olho nú identificarmos qual observação é maior através do gráfico. Esse tipo de gráfico pode acabar dificultando um pouco a análise, especialmente quando as informações estão melhor balanceadas.
#
# Além de identificar a quantidade de horas observadas, nós não conseguimos extrair mais nenhuma informação desse gráfico. Inclusive, nós temos uma espécie de regrinha, que diz que quando formos fazer algum tipo de análise, procurarmos evitar o uso de gráficos que nos remetem a comida, como por exemplo: rosca, pizza, torta, e assim por diante.
#
# Então qual tipo de gráfico poderíamos utlizar para melhorarmos nossa visualização? Vamos utilizar o gráfico de barras, através deste código:

# %%
dados['tempo'].value_counts().plot.bar()

# %% [markdown]
# Agora sim conseguimos identificar com mais facilidade qual observação tem a sua maior frequência. Na verdade a quantidade de horas com o maior número de observações foi a de 48.
#
# No eixo y temos o número que nos remete ao número de observações. Então podemos observar que tivemos pouco mais de 8000 observações relativas às 48 horas.
#
# Então, o gráfico de barras acabou sendo muit mais útil, nesse caso, do que o gráfico de pizza.

# %% [markdown]
# Ao longo da aula nós falamos sobre a expressão gênica. Se nós voltarmos à tabela, na coluna g-0, nós temos alguns valores dentro de um intervalo definido. Para não termos valores muito distantes entre si, é bastante comum no meio científico que haja uma normalização dos resultados, para criamos um intervalo que não seja tão grande, em que o meio dessa distribuição seja o 0.
#
# Como nós podemos saber em quais linhas dessa coluna, o meu valor está acima de 0?
#
# Vamos fazer uma consulta nos nossos dados, da seguinte maneira:

# %%
dados_filtrados = dados[dados['g-0'] > 0]
dados_filtrados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %% [markdown]
# Dessa maneira, temos somente as 5 primeiras linhas com o valores maiores do que 0 na coluna g-0, com a ajuda dessa máscara com o código ```[dados['g-0']>0]```.
#
# Dessa mesma forma que aplicamos essa máscara, podemos utilizar o mesmo caminho, ou outras 'querys', para responder várias outras perguntas.
#
# Assim, temos outro desafio, o #5, de procurar na documentação do pandas o método query.
#
# Além desse temos outros desafios, o #6 e o #7 e o #8, todos eles estão logo abaixo.

# %%
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %% [markdown]
# ## Desafios Aula 01

# %% [markdown]
# **Desafio 01 : Investigar por que a classe tratamento é tão desbalanceada?**
#
# Referente à essa questão, estive pesquisando que a cultura celular tem uma grande aplicação para a produção de imunológicos, como por exemplo, vacinas, onde é necessária a aplicação de corpos estranhos para verificar a reação.
#
# Quando se utilizam o método "com_controle" apenas é inserido o valor "cacb2b860" na variável "droga", o que pode corresponder a ausência da utilização de drogas no experimento.

# %%
dados_com_controle = dados[dados['tratamento'] == "com_controle"]
dados_com_controle['droga'].value_counts()
# Out:
# cacb2b860    1866
# Name: droga, dtype: int64

# %% [markdown]
# **Desafio 02 : Plotar as 5 últimas da tabela**
#
# Para resolver essa questão, podemos utilizar o comando .tail().
#
# Uma dica para pensar na utilização do .head() ou .tail() é realizar a tradução para o Português, onde "head" significa cabeça (parte de cima) e "tail" significa cauda (parte de baixo).

# %%
dados.tail()
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %% [markdown]
# **Desafio 03 : Proporção das classes tratamento**
#
# Podemos identificar com o comando abaixo que temos uma disparidade entre os valores "com_droga" (92.16%) e "com_controle" (7.83%) da variável "tratamento".

# %%
dados['tratamento'].value_counts(normalize = True) * 100
# Out:
# com_droga       92.164273
# com_controle     7.835727
# Name: tratamento, dtype: float64

# %% [markdown]
# **Desafio 04 : Quantos tipos de drogas foram utilizados?**
#
# Podemos responder essa questão utilizando o comando .nunique() que retorna a quantidade de valores distintos para a variável "droga".

# %%
print(f"Foram identificadas {dados['droga'].nunique()} drogas utilizadas na cultura celular.")
# Out:
# Foram identificadas 3289 drogas utilizadas na cultura celular.

# %% [markdown]
# **Desafio 05 : Procurar na documentação o método query(pandas)**
#
# Link para a documentação : [Documentação Pandas Query](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.query.html)
#
# Abaixo, estou trazendo 2 exemplos de utilização do método .query(), sendo um para retornar os valores de 'tempo' igual à 24 e outro para demonstrarmos um erro na utilização.

# %%
dados.query('tempo == 24')
# Out:
#                  id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 5      id_001762a82  com_droga     24   D1  ...  1.2120  0.3765  0.7848  1.3990
# 6      id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 17     id_0031dd989  com_droga     24   D2  ...  0.8093 -0.0269  0.4259  0.9279
# 32     id_006e27d96  com_droga     24   D2  ...  0.0691  0.1536  0.2948 -0.9860
# ...             ...        ...    ...  ...  ...     ...     ...     ...     ...
# 23802  id_fff3976bd  com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23804  id_fff506720  com_droga     24   D1  ... -0.4097  0.2282 -0.3213 -0.0836
# 23809  id_fffb1ceed  com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c  com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23812  id_fffcb9e7c  com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
#
# ...

# %%
# Caso queira verificar que querys utilizando variáveis com hífen(-) no nome ocorrem erros, podes remover o '#' da linha abaixo :
# dados.query('g-0 > 0')

# %% [markdown]
# **Desafio 06 : Renomear as colunas tirando o hífen.**
#
# Para resolvermos essa questão, podemos utilizar os métodos combinados .columns.str.replace('-', ''), onde :
#
# .columns = Retorna os nomes de nossas colunas
#
# .str.replace('-', '') = Realiza a remoção dos hífens("-")

# %%
dados.columns = dados.columns.str.replace('-', '')
dados.columns
# Out:
# Index(['id', 'tratamento', 'tempo', 'dose', 'droga', 'g0', 'g1', 'g2', 'g3',
#        'g4',
#        ...
#        'c90', 'c91', 'c92', 'c93', 'c94', 'c95', 'c96', 'c97', 'c98', 'c99'],
#       dtype='object', length=877)

# %%
# Podemos verificar que após a remoção do hífen, conseguimos realizar o .query()
dados.query('g0 > 0').head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %% [markdown]
# **Desafio 07 : Deixar os gráficos bonitões com Matplotlib.pyplot**

# %%
# Realizar a importação do pyplot
import matplotlib.pyplot as plt

# %%
plt.pie(dados['tratamento'].value_counts(), explode=[0, 0.1], autopct='%1.2f%%', shadow = True)
plt.title('Proporção valores da variável tratamento')
plt.legend(labels = dados['tratamento'].unique(), loc = 'best')
plt.show()

# %%
dados['tempo'].value_counts().sort_index().plot.bar()
plt.title("Horas x Quantidade de valores", fontsize = 15)
plt.xlabel("Horas", fontsize = 12)
plt.ylabel("Quantidade", fontsize = 12)
plt.xticks(rotation = 0)
plt.show()

# %%
plt.figure(figsize = (12,8))
dados_com_droga = dados[dados['tratamento'] == 'com_droga']
dados_com_droga['droga'].value_counts().head(10).plot.bar()
plt.xticks(rotation = 0)
plt.xlabel("Droga", fontsize = 16)
plt.ylabel("Quantidade", fontsize = 16)
plt.title("Quantidade das 10 drogas mais utilizadas", fontsize = 20)
plt.show()

# %% [markdown]
# **Desafio 08 : Resumo do que você aprendeu com os dados**
#
# Até o momento, aprendemos com os dados que nos estudos sobre a cultura de células foram utilizadas 3289 tipos de drogas diferentes, onde tivemos doses diferentes sendo aplicadas (D1 e D2) e aonde a expressão génica de cada amostra foi analizada em 3 intervalos de tempo diferentes (24h, 48h e 72h), sendo 48h a mais utilizada.

# %% [markdown]
# # Aula 02
#
# Olá!
#
# Seja bem vindo e bem vinda a aula 02!
#
# Na aula 01, nós começamos a explorar um conjunto de dados relacionados à industria farmacêutica. Para isso nós utilizamos uma biblioteca muito conhecida no mundo de DataScience: o Pandas.
#
# Nós utilizamos o Pandas para abrir o dataset, que estava no formato CSV, e para gerar um dataframe, uma tabela, para então começarmos a analisar e entender o que significava cada coluna. Com a ajuda da Vanessa, especialista na área, identificamos que temos colunas que nos remetem a dados que estão sob tratamento(droga) e com controle. Além disso, temos também diversas colunas que remetem aos genes.
#
# Começamos nossa análise olhando para cada coluna de forma separada e também geramos gráficos, para auxiliar nossa análise.
#
# Agora, vamos mergulhar juntos na aula 02!

# %%
dados
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %% [markdown]
# A base de dados que usamos até o momento possuí uma variável chamada ```droga```, mas foi explicado pela Vanessa que essa não e a melhor nomenclatura para representa-la.
#
# Por isso, vamos usar a função ```map``` da biblioteca Pandas para renomear essa coluna.
#
# É importante destacar que passamos o parâmetro ```inplace = True``` para que os dados sejam modificados no local e o dataframe será atualizado.

# %%
dados.rename(columns = {"droga" : "composto"}, inplace = True)

# %% [markdown]
# Com a utilização da função ```head````podemos apresentar as 5 primeiras linhas e conferir se a renomeação ocorreu da maneira que estavámos esperando.

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# Queremos melhorar a visualização do nosso histograma de compostos e, como existem mais de 3.000 variações na nossa base de dados, decidimos elencar os 5 compostos que mais aparecem.
#
# Para isso, vamos utilizar a função ```value_counts``` e também iremos declarar o ```index[0:5]``` para apresentar os maiores valores que estão no intervalo [0,5[ (5 não incluído), ou seja, o nome dos 5 maiores valores.

# %%
cod_compostos = dados['composto'].value_counts().index[0:5]
cod_compostos

# Também podemos utilizar o head da seguinte forma abaixo :
# cod_compostos = dados['composto'].value_counts().head(5).index
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %% [markdown]
# Existem algumas maneiras de filtrar uma base de dados e optamos em usar a função ```query``` do Pandas, uma função bastante análoga ao SQL. A estrutura é bastante simplificada, precisamos apenas definir o dataframe, chamar a função e passar como parâmetro a condição que deve ser filtrada no nosso conjunto de dados.
#
# Nesta parte, queremos realizar um filtro em nossos dados, selecionando apenas as linhas nas quais o composto esteja na lista ```cod_compostos```.
#
# Usamos ```composto``` porque é a coluna a ser verificada no dataframe e ```cod_compostos``` por ser a lista com os top 5 compostos. Um detalhe é que devemos utilizar @ para informar o ```query``` que ```cod_compostos``` é uma variável que já foi definida fora da função.

# %%
dados.query('composto in @cod_compostos')
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5     com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %% [markdown]
# Agora que verificamos que a nossa filtragem funcionou corretamente e temos uma base de dados com 3.235 linhas, podemos usar a função ```query``` como parâmetro para o ```countplot```, o nosso gráfico de barras.
#
# O ```countplot``` é um gráfico pré-programado da biblioteca ```Seaborn``` e, por isso, precisamos fazer a importação da mesma. Adicionalmente, no Google Colaboratory, para que possamos enxergar o gráfico com os padrões de configuração da biblioteca, precisamos rodar ```sns.set()```.
#
# Além disso, para refinar a apresentação do gráfico, podemos utilizar algumas funcionalidades da biblioteca ```Matplotlib``` (fazendo, primeiramente, sua importação - ```import matplotlib.pyplt as plt```).
#
# Também estamos definindo o tamanho do gráfico através da função ```figure``` e seu parâmetro ```figsize=(x, y))``` e o título através do ```set_title('Título')```.
#
# Como comentado na aula, usualmente, armazenamos o nosso gráfico em uma variável ```ax``` e então, definimos as demais configurações (por exemplo, ```ax.set_title('Título')```.
#
# E, finalmente, para visualizar o gráfico de barras, usamos o ```plt.show()```.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()
plt.figure(figsize=(8,6))
ax = sns.countplot(x = 'composto', data = dados.query('composto in @cod_compostos'), order = cod_compostos)
ax.set_title("Top 5 compostos", fontsize = 20)
ax.set_xlabel("Composto", fontsize = 16)
ax.set_ylabel("Quantidade", fontsize = 16)
plt.show()

# %% [markdown]
# Até o momento analisamos os dados de tempo, dose, compostos e afins. Entretanto, não analisamos os dados de expressões gênicas (G's) e viabilidade celular (C's).
#
# Mas será que podemos criar um gráfico de barras para esses dados?

# %%
len(dados['g0'].unique())
# Out:
# 14367

# %% [markdown]
# Como temos diversos compostos únicos dentro da coluna ```g0```, não é viável que façamos o mesmo gráfico utilizado anteriormente.
#
# Por isso, precisamos traçãr uma nova estratégia para visualizar os nossos dados aqui, usaremos um histograma.
#
# O primeiro passado, é identificar qual o valor mínimo (min()) e o valor máximo (max()) para entender qual o intervalo numérico com o qual estamos trabalhando.

# %%
dados['g0'].min()
# Out:
# -5.513

# %%
dados['g0'].max()
# Out:
# 10.0

# %% [markdown]
# Depois que reconhecemos que o intervalo vai de ~ 5,5 a 10,0, podemos partir para o histograma e a função que usaremos para plotar é do Pandas (.hist()).
#
# Acresentamos um parâmetro dentro da função (bins = número de quebras) para melhor dividir e, consequentemente visualizar os dados.
#
# Quando definimos os bins em 100, podemos perceber que a forma se aproxima bastante de uma curva bastante conhecida: a distribuição normal.

# %%
plt.figure(figsize = (8,6))
ax = dados['g0'].hist(bins=100)
ax.set_title('Histograma valores g0', fontsize = 20)
ax.set_xlabel('Valores g0', fontsize = 16)
ax.set_ylabel('Quantidade', fontsize = 16)
plt.show()

# %%
plt.figure(figsize = (8,6))
ax = dados['g19'].hist(bins=100)
ax.set_title('Histograma valores g19', fontsize = 20)
ax.set_xlabel('Valores g19', fontsize = 16)
ax.set_ylabel('Quantidade', fontsize = 16)
plt.show()

# %% [markdown]
# Podemos utilizar a função ```describe``` do Pandas que já calcula e descreve algumas estatísticas importantes para o entendimento dos dados (contagem, média, desvio padrão, mínimo, quartis e máximo).

# %%
dados.describe()
# Out:
#               tempo            g0  ...           c98           c99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %% [markdown]
# Uma estratégia mais direta em que não precisaremos escrever a lista gene a gene, é o uso da função loc[] do Pandas. Como argumentos, passamos primeiramente o :, os dois pontos faz com que o loc[] retorne todos os elementos de uma determinada coluna, isso é importante quando não sabemos qual a quantidade de linhas de um dataframe. E, o segundo elemento, passamos as colunas que são de nosso interesse. No caso, queremos que a função nos retorne todos os elementos das colunas g-0 até g-771. E, por fim, podemos declarar a nossa função de interesse a partir deste filtro realizado nos dados, o describe().

# %%
dados.loc[:, 'g0' : 'g771'].describe()
# Out:
#                  g0            g1  ...          g770          g771
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean       0.248366     -0.095684  ...     -0.219210      0.101524
# std        1.393399      0.812363  ...      1.326193      1.417674
# min       -5.513000     -5.737000  ...    -10.000000    -10.000000
# 25%       -0.473075     -0.562200  ...     -0.554400     -0.523800
# 50%       -0.008850     -0.046600  ...      0.028700     -0.006500
# 75%        0.525700      0.403075  ...      0.496400      0.536950
# max       10.000000      5.039000  ...     10.000000     10.000000
#
# [8 rows x 772 columns]

# %% [markdown]
# Apesar do describe reunir as nossas estatísticas de interesse, é bastante complexo analisar o dataframe resposta.
#
# Para facilitar o nosso entendimento, vamos plotar histogramas que nos ajudarão na visualização das estatísticas de todas as colunas selecionadas.
#
# Não queremos realizar o histograma coluna a coluna (genes) e sim a partir das linhas (estatísticas). Por isso, vamos tronspor as linhas e colunas utilizando ```.T[]``` no código anterior que produzimos para organizar o ```describe()```

# %%
dados.loc[:,'g0' : 'g771'].describe().T.head()
# Out:
#       count      mean       std    min       25%      50%       75%     max
# g0  23814.0  0.248366  1.393399 -5.513 -0.473075 -0.00885  0.525700  10.000
# g1  23814.0 -0.095684  0.812363 -5.737 -0.562200 -0.04660  0.403075   5.039
# g2  23814.0  0.152253  1.035731 -9.104 -0.437750  0.07520  0.663925   8.257
# g3  23814.0  0.081971  0.950012 -5.998 -0.429575  0.00805  0.463400  10.000
# g4  23814.0  0.057347  1.032091 -6.369 -0.470925 -0.02690  0.465375  10.000

# %% [markdown]
# Abaixo, realizaremos o plot dos valores das médias e dos valores máximos e mínimos.

# %%
dados.loc[:,'g0':'g771'].describe().T['mean'].hist(bins=30)

# %%
dados.loc[:,'g0':'g771'].describe().T['min'].hist(bins=30)

# %%
dados.loc[:,'g0':'g771'].describe().T['max'].hist(bins=30)

# %% [markdown]
# É muito interessante replicar a análise desenvolvida para os ```genes (g)``` nos ```tipos celulares (c)```.

# %%
dados.loc[:,'c0':'c99'].describe().T['mean'].hist(bins=50)

# %%
dados.loc[:,'c0':'c99'].describe().T['min'].hist(bins=50)

# %%
dados.loc[:,'c0':'c99'].describe().T['max'].hist(bins=50)

# %% [markdown]
# Um outro tipo de gráfico super interessante e útil é o boxplot. Para visualizá-lo vamos usar a função ````boxplot``` do Seaborn e, como argumentos vamos passar um x, onde x = coluna que será plotada neste eixo e a base de dados ```data = conjunto de dados```.
#
# O boxplot apresenta uma caixa no meio onde podemos identificar a mediana (linha no meio da caixa), os outlieres (pontos acima ou abaixo do eixo principal do gráfico), a maior concentração dos dados (primeiro quartil 25% e terceiro quartil 75%) e os máximos e mínimos desconsiderando os outliers.

# %%
sns.boxplot(x = 'g0', data = dados)

# %% [markdown]
# Podemos também definir os dados para o eixo Y, atribuindo um valor para o paramêtro ```y```.

# %%
plt.figure(figsize = (10,8))
sns.boxplot(y = 'g0', x = 'tratamento', data = dados)

# %% [markdown]
# ## Desafios Aula2

# %% [markdown]
# **Desafio 01 : Ordenar o gráfico countplot**
#
# **Desafio 02: Melhorar a visualização alterando tamanho da fonte**
#
# Para a realização dos dois desafios, iremos utilizar o parâmetro ```order``` do sns.countplot para a ordenação e o parâmetro ```fontsize``` para alteração do tamanho da fonte.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()
plt.figure(figsize=(8,6))
ax = sns.countplot(x = 'composto', data = dados.query('composto in @cod_compostos'), order = dados['composto'].value_counts().index[0:5], palette = "BuPu")
ax.set_title("Top 5 compostos", fontsize = 20)
ax.set_xlabel("Composto", fontsize = 16)
ax.set_ylabel("Quantidade", fontsize = 16)
plt.show()

# %% [markdown]
# **Desafio 03: Plotar os histogramas com seaborn**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize = (8,6))
ax = sns.histplot(x = 'mean', data = dados.loc[:,'g0':'g771'].describe().T, bins = 30)
ax.set_title("Histograma Médias Genes")
ax.set_xlabel("Média")
ax.set_ylabel("Quantidade")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize = (8,6))
ax = sns.histplot(x = 'min', data = dados.loc[:,'g0':'g771'].describe().T, bins = 30)
ax.set_title("Histograma Valores Mínimos Genes")
ax.set_xlabel("Valores Mínimos")
ax.set_ylabel("Quantidade")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize = (8,6))
ax = sns.histplot(x = 'max', data = dados.loc[:,'g0':'g771'].describe().T, bins = 30)
ax.set_title("Histograma Valores Máximos Genes")
ax.set_xlabel("Valores Máximos")
ax.set_ylabel("Quantidade")
plt.show()

# %% [markdown]
# **Desafio 04: Estudar sobre as estatíticas retornadas no .describe()**
#
# As informações retornadas com o .describe() são as seguintes :
#
# - count = Quantidade de elementos
# - mean = Média dos elementos (soma / total de observações)
# - std = Desvio Padrão (medida de variação em torno da média, onde quanto mais perto de 0, mais os dados são homogêneos)
# - min = Valor mínimo
# - 25% = Primeiro quartil (valor onde 25% dos dados estão abaixo)
# - 50% = Segundo quartil ou Mediana (valor onde 50% dos dados estão abaixo)
# - 75% = Terceiro quartil (valor onde 75% dos dados estão abaixo)
# - max = Quarto quartil ou Valor maximo (valor onde 100% dos dados estão abaixo)

# %%
dados.describe()
# Out:
#               tempo            g0  ...           c98           c99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %% [markdown]
# **Desafio 05 : Refletir sobre a manipulação do tamanho das visualizações.**
#
# Podemos verificar com o exemplo abaixo como os gráficos podem se diferenciar de acordo com a quantidade de barras (bins) que serão utilizadas.
#
# No primeiro gráfico, utilizei a quantidade de bins (10), onde podemos verificar um intervalo maior no eixo X para cada barra e um aumento na quantidade verificada.
#
# No segundo gráfico, foi utilizada a quantidade de bins (200), onde podemos verificar um intervalo menor no eixo X para cada barra e uma diminuição na quantidade do eixo Y.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize = (15,5))

sns.histplot(x = 'mean', data = dados.loc[:,'g0':'g771'].describe().T, bins = 10, ax = axes[0])
sns.histplot(x = 'mean', data = dados.loc[:,'g0':'g771'].describe().T, bins = 200, ax = axes[1])

axes[0].set_title('Histograma com bins 10')
axes[0].set_xlabel("Médio")
axes[0].set_ylabel("Quantidade")

axes[1].set_title('Histograma com bins 200')
axes[1].set_xlabel("Médio")
axes[1].set_ylabel("Quantidade")

fig.suptitle("Diferença de Histogramas com bins distintos")

plt.show()

# %% [markdown]
# **Desafio 06: Fazer outras análises com o boxplot e até com o histograma.**

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

dados_comdroga = dados.query('tratamento == "com_droga"')
dados_composto_30 = dados_comdroga["composto"].value_counts().head(30).index
dados_comdroga_30 = dados.query('composto in @dados_composto_30')

plt.figure(figsize = (12,8))
sns.countplot(y = "composto", data = dados_comdroga_30, palette = "Reds_r", order=dados_composto_30)
plt.xlabel("Quantidade do composto", fontsize = 16)
plt.ylabel("Composto utilizado", fontsize = 16)
plt.title("Top 30 Compostos utilizados", fontsize = 20)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

dados_comdroga = dados.query('tratamento == "com_droga"')
dados_composto_8 = dados_comdroga["composto"].value_counts().head(8).index
dados_comdroga_8 = dados.query('composto in @dados_composto_8')

plt.figure(figsize = (12,8))
sns.countplot(x = "composto", data = dados_comdroga_8, palette = "BuPu", order=dados_composto_8, hue = 'tempo')
plt.xlabel('Composto', fontsize = 16)
plt.ylabel('Quantidade', fontsize = 16)
plt.title('Quantidade dos 8 compostos mais utilizados e separação por tempo', fontsize = 20)
plt.show()

# %% [markdown]
# **Desafio 07: Resumo do que você aprendeu com os dados**
#
# Com as funções e gráficos na aula 02, aprendemos que os valores das colunas dos genes (gx) possuem uma distribuição normal (maior quantidade de valores no meio) quando plotados os gráficos das médias. Também identificamos plotando os gráficos de valores máximos e mínimos que seus dados foram normalizados para trabalharem no intervalo de [-10, 10].
#
# Outra verificação importante foi o gráfico de boxplot, onde verificando os valores da variável 'g0' verificamos uma enorme quantidade de outliers (valores extremos) quando utilizado o tratamento ```com_droga```.
#
# Outra situação interessante que verifiquei plotando o gráfico de 30 compostos utilizados no tratamento ```com_droga```, verifiquei que apenas 8 ultrapassam a quantidade de 100x utilizados.
#
# Após essa verificação realizei a plotagem desses 8 compostos mais utilizados e realizadas a separação por tempo, onde validamos que o tempo de 48 horas é o mais utilizado em cada composto.

# %% [markdown]
# # Aula 03
#
# Olá Cientista!
#
# Seja bem vindo e bem vinda à aula 03!
#
# Na aula anterior, pudemos entender a importância da construção de gráficos na visualização dos dados. Discutimos principalmente os histogramas e boxplots e, além disso, também falamos sobre a função describe do Pandas.
#
# Hoje, nosso foco é nos aprofundar ainda mais na base de dados e entender mais sobre a relação entre as nossas variáveis.
#
# Olhando para o nosso conjunto de dados, percebemos que temos dados de tratamento, tempo, dosagem, composto químico usado e os dados genéticos. E os primeiros dados que vamos relacionar são aqueles ligados ao tratamento e, como já vimos anteriormente, estes são dados categóricos.
#
# Um dos vieses de análise está relacionado às proporções destas categorias e, como aprendemos na aula anterior, um gráfico de frequências pode ser muito útil nesse aspecto.

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# Conforme busca na documentação do Pandas, encontramos uma maneira para construir uma tabela de frequêcias, a função ```crosstab```.
#
# Esta função recebe como argumentos os dados que gostaríamos de correlacionar de uma maneira bem simples : crosstab(dataframe['coluna1'], dataframe['coluna2']) e então, como retorno, temos uma matriz que relaciona essas variáveis a partir da frequência.

# %%
pd.crosstab(dados['dose'], dados['tempo'])
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %% [markdown]
# Entretando, na matriz acima não estamos considerando ao tratamento usado, apesar desta variável ser de suma importância, visto que decide se há ou não presença de um composto no evento.
#
# O código final para o comando será ```crosstab(dataframe[['coluna1'], dataframe['coluna2']], dataframe['coluna3']```, onde ```coluna 1``` e ```coluna 2``` são as nossas linhas e ```coluna 3 ``` a nossa coluna.

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'])
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %% [markdown]
# Apesar de já termos construído uma tabela bem interessante através da frequência de algumas variáveis, podemos explorar a proporção destes dados em si.
#
# Para essa informação, devemos utilizar o parâmetro ```normalize = 'index'```, realizando a comparação entre as categorias (soma da linha deve dar 1).
#
# Caso utilizarmos ```normalize == True``` será criada a proporção da tabela inteira, não apenas de cada linha.

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize = True)
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.012640   0.150542
#      48         0.014403   0.168430
#      72         0.012892   0.151172
# D2   24         0.012808   0.150374
#      48         0.012808   0.150794
#      72         0.012808   0.150332

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize = 'index')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %% [markdown]
# Podemos também agregar à nossa matriz uma métrica estatística associada a uma coluna. Para que isso seja realizado, adicionamos mais 2 parâmetros à nossa função ```crosstab``` : o primeiro é o ```values = dataframe['variavel']``` e o segundo é o ```aggfunc``` que recebe como parâmetro alguma métrica estatística, como a média (```aggfunc  = 'mean'```).

# %%
pd.crosstab([dados['dose'], dados['tempo']],  dados['tratamento'], values=dados['g0'], aggfunc='mean')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %% [markdown]
# Para variáveis contínuas, fazer tabelas de frequências não é a melhor estratégia para analisá-las. Mas, construir um novo tipo de gráfico pode ser muito interessante para o nosso processo.
#
# Para fins de visualização, o primeiro passo é filtrar a nossa base de dados com as colunas que queremos investigar.

# %%
dados[['g0', 'g3']]
# Out:
#            g0      g3
# 0      1.0620 -0.6208
# 1      0.0743  0.0604
# 2      0.6280 -0.0764
# 3     -0.5138  0.5288
# 4     -0.3254  0.6919
# ...       ...     ...
# 23809  0.1394 -0.5080
# 23810 -1.3260  0.9905
# 23811  0.3942 -0.7389
# 23812  0.6660  0.2044
# 23813 -0.8598  0.7952
#
# [23814 rows x 2 columns]

# %% [markdown]
# Para realizar a visualização, podemos utilizar o ```scatterplot (Gráfico de Dispersão)```, um tipo de gráfico da biblioteca Seaborn que recebe a variável que vai ser usada no eixo x, a variável do eixo y e o conj-utno de dados.
#
# ```sns.scatterplot(x ='variavel eixo x', y = 'variavel eixo y', data = dados```
#
# O gráfico de dispersão utiliza os dados como uma coleção de pontos cartesianos e ele é usado para apurar se há relação de causa e efeito entre 2 variáveis quantitativas.
#
# Mas, a partir do gráfico de dispersão, não podemos dizer que uma variável afeta a outra, podemos apenas definir se há relação entre elas e qual a intensidade disso.
#
# **Observação : Relação não é causalidade!**

# %%
plt.figure(figsize = (10,6))
sns.scatterplot(x = 'g0', y = 'g3', data = dados)
plt.title("Gráfico de dispersão variável g0 x g3", fontsize = 18)
plt.show()

# %% [markdown]
# Observando o gráfico acima, não parecemos encontrar nenhum padrão definido.
#
# Iremos alterar nossas variáveis para verificar se encontramos um padrão melhor defindido. Aqui, iremos utilizar ```g0``` para o eixo x e a variável ```g8``` para o eixo y.
#
# Como retorno, recebemos um gráfico de dispersão que aparenta uma correlação negativa entre as 2 variáveis (a médida que ```g0``` aumenta, verificamos uma diminuição no valor de ```g8```)

# %%
plt.figure(figsize = (10,6))
sns.scatterplot(x = 'g0', y = 'g8', data = dados)
plt.title("Gráfico de dispersão variável g0 x g8", fontsize = 18)
plt.show()

# %% [markdown]
# E, como parte do nosso trabalho é levantar hipóteses e confirmá-las (ou não), precisamos verificar se a nossa suspeita de que a relação entre as variáveis g-0 e g-8desenha uma curva com inclinação negativa.
#
# Para isso, vamos utilizar uma outra função do Seaborn, a ```lmplot```. A lmplot vai desenhar no nosso gráfico de dispersão uma linha de tendência e, assim, poderemos confirmar o padrão daquele conjunto de dados.
#
# Os parâmetros a serem recebidos, são muito parecidos com aqueles usados no ```scatterplot```. Então teremos :
#
# ```sns.lmplot(data=base de dados, x='variavel para o eixo x', y='variavel para o eixo y', line_kws={'color': 'cor da linha de tendencia'})```

# %%
sns.lmplot(data = dados, x = 'g0', y = 'g8', line_kws = {'color' : 'red'})

# %% [markdown]
# Para uma análise mais real e completa, é interessante separarmos ainda mais o nosso conjunto de dados. Isso porque, na imagem acima, apesar de termos uma linha de tendência para a relação entre os dados g0 e g8, não há filtros para a dosagem, tratamento e o tempo.
#
# Acrescentaremos o parâmetro ```col = 'tratamento'``` para que sejam plotados gráficos de acordo com as categorias da variável em questão nas colunas (com_droga e com_controle) e também incluímos o parâmetro ```row = 'tempo'``` para que mais uma subdivisão seja feita, e as linhas apresentem novos gráficos com as diferentes categorias (24, 48 e 72).

# %%
sns.lmplot(data = dados, x = 'g0', y = 'g8', line_kws = {'color'  : 'red'}, col = 'tratamento', row = 'tempo')
plt.show()

# %% [markdown]
# Outra medida para analisar como as variáveis estão associadas é a correlação.
#
# Para isso, vamos usar a função ```loc``` e vamos agregar o ```.corr```. O ```loc``` serve para definirmos o intervalo em que a correlação vai ser calculada.
#
# Como retorno, temos uma tabela bem grande que correlaciona a variável e apresenta valores entre -1 e 1, onde :
#
#     - Valores muito próximos de 1 ou -1: variáveis altamente correlacionadas
#     - Valores muito próximos de 0: variáveis pouco ou não correlacionadas
#
# E, o que diferencia se essa correlação será proporcional ou inversamente proporcional, será o sinal :
#
#     - Valores muito próximos de 1 : proporcionalmente correlacionadas
#     - Valores muito próximos de -1: inversalmente proporcionais.

# %%
dados.loc[:,'g0' : 'g771'].corr()
# Out:
#             g0        g1        g2  ...      g769      g770      g771
# g0    1.000000  0.086032  0.176188  ... -0.127375 -0.514201  0.405908
# g1    0.086032  1.000000 -0.054518  ... -0.006866 -0.095108 -0.032233
# g2    0.176188 -0.054518  1.000000  ...  0.014489 -0.078661  0.103985
# g3    0.011266 -0.027855  0.042633  ... -0.206077 -0.002142  0.058219
# g4    0.403153  0.193647  0.013968  ... -0.172727 -0.363673  0.250713
# ...        ...       ...       ...  ...       ...       ...       ...
# g767 -0.052622 -0.003378 -0.053149  ...  0.065450  0.008603 -0.001136
# g768  0.300241 -0.030756  0.115415  ...  0.079364 -0.382607  0.351651
# g769 -0.127375 -0.006866  0.014489  ...  1.000000  0.135853 -0.083713
# g770 -0.514201 -0.095108 -0.078661  ...  0.135853  1.000000 -0.425063
# g771  0.405908 -0.032233  0.103985  ... -0.083713 -0.425063  1.000000
#
# [772 rows x 772 columns]

# %% [markdown]
# Analisar essa tabela é um desafio bem grande. Então como auxílio visual costumamos plotar um mapa de calor para que possamos identificar com maior facilidade a correlação entre as variáveis.
#
# E, como esse código já está construído na própria documentação do Seaborn, vamos copiar o [código](https://seaborn.pydata.org/examples/many_pairwise_correlations.html) de lá, fazendo apenas algumas pequenas alterações.
#
# Adicionalmente, também fizemos a importação da biblioteca Numpy que é usada para gerar este mapa de calor (```import numpy as np```).

# %%
corr = dados.loc[:,'g0' : 'g50'].corr()

# %% [markdown]
# O mapa de calor mostra uma escala de cores em sua lateral direita, a legenda e, para cada pontinho, podemos perceber a força da correlação sendo mostrada através de uma cor associada.
#
# Olhando para o nosso gráfico, percebemos que, em sua maioria, as expressões genicas não apresentam correlações tão altas entre si (podemos deduzir isso observando que o gráfico em grande parte é translúcido).
#
# É importante destacar que não podemos inferir causalidade a partir da correlação, como já descrevemos anteriormente no gráfico de dispersão. Exemplificando: vimos que g-0 e g-8 têm correlação inversamente proporcional entre si mas não podemos concluir que é o g-0 que faz o g-8 diminuir, ou seja, a causa.

# %%
import numpy as np

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# Agora, vamos repetir o processo de construção do mapa de calor para a a viabilidade celular (c).
#
# Definimos uma nova variável corr_celular e ajustamos os parâmetros de acordo com os nossos cs.
#
# Observando o gráfico de saída, podemos perceber uma grande diferença entre os dois mapas de calor que construímos. A escala deste novo gráfico é bem diferente da escala anterior, temos valores apenas entre 0,65 e 0,90, correlações altamente proporcionais.

# %%
corr_celular = dados.loc[:,'c0':'c50'].corr()

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_celular, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_celular, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# ## Desafios Aula 03

# %% [markdown]
# **Desafio 01: Criar tabelas de frequência com pandas.groupby()**

# %%
dados.groupby(['dose', 'tempo'])['tratamento'].value_counts().unstack()
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %% [markdown]
# Também podemos realizar a construção da tabela de frequência utilizando ```.pivot_table()```

# %%
dados.pivot_table(index = ['dose', 'tempo'], columns = ['tratamento'], aggfunc={'tratamento' : len})
# Out:
#              tratamento
# tratamento com_controle com_droga
# dose tempo
# D1   24             301      3585
#      48             343      4011
#      72             307      3600
# D2   24             305      3581
#      48             305      3591
#      72             305      3580

# %% [markdown]
# **Desafio 02: Normalizar o crosstab pela coluna.**
#
# Para realizar a normalização no crosstab, podemos utilizar o parâmetro ```normalize = ....```, onde temos as opções :
#
#     - True = normalização da tabela inteira
#     - 'columns' = normalização por coluna
#     - 'index' = normalização por linhas

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize = 'columns')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.161308   0.163341
#      48         0.183816   0.182750
#      72         0.164523   0.164024
# D2   24         0.163451   0.163158
#      48         0.163451   0.163614
#      72         0.163451   0.163113

# %% [markdown]
# **Desafio 03: Explorar outros agregadores.**
#
# Assim como o ```.describe()``` podemos utilizar diversos agregadores, como por exemplo ```.std()``` para verificarmos o desvio padrão ou ```.mean()``` para verificarmos as médias.
#
# Abaixo temos os exemplos com a variável ```g0``` e os valores para os diferentes valores de ```dose```, ```tratamento```, ```tempo```.

# %%
dados.groupby(['dose', 'tempo', 'tratamento'])['g0'].std().unstack()
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.751395   1.461954
#      48         0.853396   1.693903
#      72         0.769294   1.458600
# D2   24         0.836626   1.044999
#      48         0.836845   1.315476
#      72         0.878041   1.451532

# %%
dados.groupby(['dose', 'tempo', 'tratamento'])['g0'].mean().unstack()
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %% [markdown]
# **Desafio 04: Explorar o melt.**
#
# melt() é uma função que coloca nossas variáveis em uma coluna denominada ```variable``` e seu respectivo valor em ```value```.
#
# Conforme exemplo abaixo, realizamos a separação por ```dose```, ```tempo``` e ```tratamento``` no parâmetro ```id_vars``` e gostaríamos de saber os valores de ```g0``` e ```g1``` setados no parâmetro ```value_vars```.
#
# Documentação para o [pandas.melt](https://pandas.pydata.org/docs/reference/api/pandas.melt.html).

# %%
pd.melt(dados,id_vars=['dose','tempo','tratamento'],value_vars=['g0', 'g1'])
# Out:
#       dose  tempo    tratamento variable   value
# 0       D1     24     com_droga       g0  1.0620
# 1       D1     72     com_droga       g0  0.0743
# 2       D1     48     com_droga       g0  0.6280
# 3       D1     48     com_droga       g0 -0.5138
# 4       D2     72     com_droga       g0 -0.3254
# ...    ...    ...           ...      ...     ...
# 47623   D2     24     com_droga       g1 -0.0636
# 47624   D2     24     com_droga       g1  0.3478
# 47625   D2     48  com_controle       g1  0.3756
# 47626   D1     24     com_droga       g1  0.2324
# 47627   D1     72     com_droga       g1  1.0240
#
# [47628 rows x 5 columns]

# %% [markdown]
# **Desafio 05: Calcular e analisar a correlação entre G e C. Refletir sobre os efeitos biológicos.**

# %% [markdown]
# Nessa primeira parte, iremos realizar o filtro da variável ```tratamento``` para pegarmos o tratamento com drogas.
#
# Após isso, realizei a criação de uma [expressão regular](https://pt.wikipedia.org/wiki/Express%C3%A3o_regular) para retornarmos apenas as colunas de g0-g50 e c0-c50.

# %%
tabela_com_droga = dados.query('tratamento == "com_droga"')
tabela_c_g = tabela_com_droga.filter(regex="^[c|g](50|[0-4][0-9]|[0-9])$")
tabela_c_g
# Out:
#            g0      g1      g2      g3  ...     c47     c48     c49     c50
# 0      1.0620  0.5577 -0.2479 -0.6208  ...  1.3070 -1.0230  0.7709  0.7180
# 1      0.0743  0.4087  0.2991  0.0604  ...  0.6065  0.6259  0.4716  0.0453
# 2      0.6280  0.5817  1.5540 -0.0764  ...  0.1787  0.3354  0.1349 -0.3569
# 3     -0.5138 -0.2491 -0.2656  0.5288  ... -1.3390 -3.0160 -3.0040 -2.8880
# 4     -0.3254 -0.4009  0.9700  0.6919  ... -0.2353 -0.1285 -0.1740  0.3559
# ...       ...     ...     ...     ...  ...     ...     ...     ...     ...
# 23808  0.1608 -1.0500  0.2551 -0.2239  ...  0.3631 -0.0474 -0.6761  0.6650
# 23809  0.1394 -0.0636 -0.1112 -0.5080  ... -0.6097  0.7577  0.0365  0.1181
# 23810 -1.3260  0.3478 -0.3743  0.9905  ... -0.7309  0.2137 -0.1295 -0.1987
# 23812  0.6660  0.2324  0.4392  0.2044  ...  0.5460 -0.7703 -0.1128  0.9409
# 23813 -0.8598  1.0240 -0.1361  0.7952  ... -0.7138 -1.6730 -1.4890 -6.0290
#
# [21948 rows x 102 columns]

# %% [markdown]
# Após isso, realizamos a criação de uma tabela de correlação (heatmap) e deixamos os valores de g0-g50 nas linhas e c0-c50 nas colunas.

# %%
corr = tabela_c_g.corr()
coor_table_filtrada = corr.loc[:'g50', 'c0':]
coor_table_filtrada.head()
# Out:
#           c0        c1        c2  ...       c48       c49       c50
# g0 -0.631908 -0.633972 -0.647684  ... -0.603942 -0.617839 -0.604046
# g1 -0.031841 -0.023024 -0.031111  ...  0.003686  0.035052  0.024609
# g2 -0.171517 -0.184193 -0.181112  ... -0.163114 -0.171502 -0.157127
# g3 -0.040447 -0.098196 -0.091010  ... -0.062495 -0.036906 -0.014167
# g4 -0.418163 -0.390767 -0.404131  ... -0.360632 -0.362597 -0.373212
#
# [5 rows x 51 columns]

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(coor_table_filtrada, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(coor_table_filtrada, center=0, cmap = cmap,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

ax.set_title("Mapa de Calor correlação c x g", fontsize = 20)
ax.set_ylabel("Genes", fontsize = 15)
ax.set_xlabel("Células", fontsize = 15)

plt.show()

# %% [markdown]
# Na matriz de correlação podemos verificar algumas situações interessantes para os genes e células :
#
# - Existem genes com uma correlação bem positiva, como por exemplo ```g30``` ou ```g41```. Isso indica que uma alta expressão desse gene está relacionado com a alta viabilidade celular (caso um valor aumente, o outro tende a aumentar).
#
# - Existem genes com uma correlação bem negativa, como por exemplo ```g38```. Isso indica que uma alta expressão do gene pode resultar em uma baixa viabilidade celular (caso um valor aumente, o outro tende a diminuir).
#
# Como observação, gostaria de enfatizar que **relação não implica causalidade**.

# %% [markdown]
# Conforme gráfico abaixo, podemos verificar a correlação entre a variável ```g30```e ```c0``` que possuí uma correlação positiva, demonstrada pela linha criada por ```.lmplot```

# %%
sns.lmplot(data = dados, x = 'g30', y = 'c0', line_kws = {'color'  : 'green'}, col = 'tratamento', row = 'tempo')
plt.show()

# %% [markdown]
# Também podemos verificar no gráfico abaixo, a correlação entre a variável ```g38```e ```c0``` que possuí uma correlação negativa, demonstrada pela linha criada por ```.lmplot```

# %%
sns.lmplot(data = dados, x = 'g38', y = 'c0', line_kws = {'color'  : 'red'}, col = 'tratamento', row = 'tempo')
plt.show()

# %% [markdown]
# **Desafio 7 : Resumo dos dados e o que aprendemos**
#
# Nessa aula, verificamos que podemos utilizar os gráficos de mapa de calor (heatmap) para verificar a correlação entre as variáveis contínuas. Nessa situação identificamos que temos genes que influenciam positivamente ou negativamente na viabilidade celular.
#
# Aprendemos também a realizar a visualização de valores utilizando o crosstab, onde podemos realizar contagens de diferentes categorias das variáveis combinadas.

# %% [markdown]
# # Aula 04
#
# Olá cientista!
#
# Seja bem vindo e bem vinda à aula 04!
#
# Na aula passada, exploramos a relação e a correlação entre nossas variáveis. Estudamos a função crosstab, gráfico de dispersão, linha de tendência, correlação entre variáveis e mapa de calor.
#
# A primeira coisa que vamos fazer para essa aula é abrir a nossa outra base de dados. Para baixá-la vamos acessar o github para copiarmos o link do arquivo. No repositório nós temos dois arquivos: os dados_experimentos.zip e o dados_arquivos.csv. Nós vamos agora trabalhar com os dados_arquivos.csv.
#
# Vamos clicar com o botão esquerdo; assim que ele abrir, vamos clicar na opção "View raw" com o botão direito, e selecionar a opção "copiar endereço do link".
#
# Vamos importar o pandas(caso você não tenha importado ainda) para nos ajudar a ler essa base de dados, através do seguinte código:

# %%
dados_resultados = pd.read_csv('https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_resultados.csv?raw=true')
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %% [markdown]
# Repare que ele demonstrou para a gente o número de colunas : 207.
#
# A primeira coluna tem o nome de "id", o que nos remete a um identificador. Além disso, as seguintes colunas possuem nomes bem complexos.
#
# Com a ajuda da Vanessa, descobrimos que esses nomes remetem aos mecanismos de ação das drogas. Ou seja, esses dados nos trazem a relação do mecanismo de ação do alvo (enzima (terminados com -ase), proteína, etc) com a droga utilizada. Ela também explicou sobre os termos "agonista" e "antagonista", que ativam o receptor e o bloqueiam, respectivamente.
#
# - Agonista refere-se às ações ou estímulos provocados por uma resposta, referente ao aumento (ativação) ou diminuição (inibição) da ativade celular.
# - Antagonistas agem como bloqueadores dos receptores, diminuindo as respostas dos neurotransmissores presentes no organismo, podendo diminuir ou anular o efeito do agonista.
#
# Agora que já sabemos que cada coluna do nosso dataframe representa um mecanismo de ação. Olhando para nosso cabeçalho percebemos que temos praticamente todos os dados com o valor 0. Será que todos dados possuem esse valor?

# %%
dados_resultados['acetylcholine_receptor_agonist'].unique()
# Out:
# array([0, 1])

# %% [markdown]
# Nosso resultado foi um array entre 0 e 1. Se quisermos fazer um teste com todos os outros mecanismos de ação também encontrará o resultado entre 0 e 1.
#
# Cada linha é o resultado do experimento da outra base de dados dos experimentos que trabalhamos. Quando um mecanismo de ação é ativado ele é indicado com 1. Quando esse mecanismo não é ativado, ele é detectado com 0.
#
# Portanto, todo resultado que obtivermos o número 1, saberemos que ele foi ativado.
#
# Vamos fazer uma investigação agora que pode ser muito interessante. Qual foi o mecanismo de ação que foi mais ativado?
#
# Vamos realizar a soma das colunas, para saber qual vai ser o que apresenta mais o número 1. Mas antes, vamos verificar se todas as minhas colunas possuem somente números ou se possuem string também nelas, através desse código.

# %%
dados_resultados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23814 entries, 0 to 23813
# Columns: 207 entries, id to wnt_inhibitor
# dtypes: int64(206), object(1)
# memory usage: 37.6+ MB

# %% [markdown]
# Conforme vimos acima no campo ```dtypes``` possuímos 206 colunas ```int64```(numéricos) e 1 coluna ```object```, que deverá ser excluída da nossa função soma.
#
# Vamos então realizar a exclusão da coluna id, que possui dados diferentes de números em sua composição, da seguinte maneira :

# %%
#dados_resultados.select_dtypes('int64').sum().sort_values(ascending = False)
contagem_moa = dados_resultados.drop('id', axis = 1).sum().sort_values(ascending = False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %% [markdown]
# No resultado há uma informação que nos chama a atenção : os inibidores, no topo do nosso resultado, são os que possuem maior quantidade de resultados positivos. Seria um ponto a se investigar.
#
# Nós fizemos uma contagem para saber onde o mecanismo de ação obteve mais respostas; agora vamos fazer outros testes.
#
# Vamos verificar se a linha específica que vamos escolher foi ativada em algum momento. E, se ela foi ativada, quantas vezes isso ocorreu?
#
# Utilizaremos o seguinte código:

# %%
dados_resultados.drop('id', axis = 1).sum(axis = 1)
# Out:
# 0        1
# 1        0
# 2        3
# 3        0
# 4        1
#         ..
# 23809    1
# 23810    1
# 23811    0
# 23812    1
# 23813    0
# Length: 23814, dtype: int64

# %% [markdown]
# E aqui tivemos o nosso resultado. Na primeira linha tivemos uma unica ativação. Já na segunda não obtivemos nenhuma. Na terceira tivemos 3, e assim por diante. Nesse que tivemos a resposta como 0, precisaríamos saber se foi um controle, ou se realmente a droga não ativou nenhuma resposta.

# %%
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# Na base de dados resultados não temos a informação que queremos, referente ao tratament. Nós apenas temos a coluna tratamento na base de dados inteira.
#
# No tratamento só temos a coluna id, e os mecanismos de ação que foram ativados por aquela coluna. Então, agora, precisamos de alguma maneira, mesclar essas informações.
#
# Antes de mesclar, vamos criar 2 novas colunas na base de dados resultado. Vamos criar uma primeira coluna que vamos chamar de n_moa(número de moas ativos), que é justamente o que havíamos calculado anteriormente.

# %%
dados_resultados['n_moa'] = dados_resultados.drop('id', axis = 1).sum(axis=1)

# %% [markdown]
# Vamos então verificar se a coluna apresenta resultados diferentes de 0; se for diferente de 0 ela retorna a mensagem 'true'; se for igual a 0 retorna ''false'

# %%
dados_resultados['n_moa'] != 0
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 23809     True
# 23810     True
# 23811    False
# 23812     True
# 23813    False
# Name: n_moa, Length: 23814, dtype: bool

# %%
dados_resultados['ativo_moa'] = (dados_resultados['n_moa'] != 0)
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %% [markdown]
# Agora que temos as duas colunas que queremos, vamos mesclar, ou então "mergear", as informações que queremos.
#
# Para isso, vamos utilizar o merge do pandas através desse código :

# %%
dados_combinados = pd.merge(dados, dados_resultados[['id', 'n_moa', 'ativo_moa']], on = 'id')
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...     c98     c99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1       True
#
# [5 rows x 879 columns]

# %% [markdown]
# Conseguimos agora a junção dos nossos dados de resultados com os dados de experimentos. Agora conseguimos responder a pergunta feita anteriormento : No tratamento eu ativei algum moa (Mecanismo de Ação) ?

# %%
dados_combinados.query('tratamento == "com_controle"')['ativo_moa'].value_counts()
# Out:
# False    1866
# Name: ativo_moa, dtype: int64

# %% [markdown]
# E obtivemos todas as respostas com o 'false'. Isso quer dizer que com controle não obtivemos nenhuma resposta de algum mecanismo de ação.
#
# Agora, será que algum tratamento que o paciente recebeu (com_droga, nesse caso) teve alguma substância que não ativou o mecanismo de ação?

# %%
dados_combinados.query('tratamento == "com_droga"')['ativo_moa'].value_counts()
# Out:
# True     14447
# False     7501
# Name: ativo_moa, dtype: int64

# %% [markdown]
# Tivemos um resultado interessante. Vemos de 14447 tiveram mecanismos de ações e 7501 não foram ativados.
#
# Vamos fazer uma análise utilizando um boxplot, que gera uma imagem onde podemos identificar a mediana (linha central) e os quartis, entendendo assim como está a distribuição dos dados.

# %%
composto_principal = dados_combinados['composto'].value_counts().head(5).index
plt.figure(figsize = (12,8))
sns.boxplot(data = dados_combinados.query('composto in @composto_principal'), y = 'g0', x = 'composto', hue = 'ativo_moa', order=composto_principal)
plt.show()

# %% [markdown]
# Analisando os boxplots, percebemos que temos algumas categorias com a mediana próxima de 0; temos outra com a mediana próxima de 5 e a outra próxima de 2.
#
# É curioso observamos que o 1º boxplot, da esquerda para a direta, está bem concentrado; esse composto específico é na verdade o composto que nos indica que foi "com tratamento".
#
# Outro ponto interessante é que o 3º boxplot é muito semelhante ao 1º; provavelmente a droga não modificou tanto assim o gene 0.

# %% [markdown]
# ## Desafios Aula 04

# %% [markdown]
# **Desafio 01 : Encontrar o top 10, das ações do MOA (inibidor, agonista...)**

# %%
dados_resultados_sufix = [name.split('_')[-1] for name in contagem_moa.index]
dados_resultados_sufix_count = pd.DataFrame(data={'acao':dados_resultados_sufix,'contagem':contagem_moa.values})
top10_acoes = dados_resultados_sufix_count.groupby(by=['acao']).sum()['contagem'].sort_values(ascending=False)[:10]

plt.figure(figsize = (14,8))

ax = sns.barplot(x = top10_acoes.values, y = top10_acoes.index)

# Inserção de valores na horizontal - https://stackoverflow.com/questions/49820549/labeling-horizontal-barplot-with-values-in-seaborn
for p in ax.patches:
    width = p.get_width()    
    ax.text(width + 1,       
            p.get_y() + p.get_height() / 2,
            '{:1.0f}'.format(width), 
            ha = 'left',   
            va = 'center') 

plt.title('Top 10 ações MOA', fontsize = 18)
plt.ylabel('Ação', fontsize = 15)
plt.xlabel('Quantidade', fontsize = 15)

plt.show()

# %%
dados_resultados_inhibitor = dados_resultados.filter(regex = '(inhibitor)')
top10_dados_resultados_inhibitor = dados_resultados_inhibitor.sum().sort_values(ascending = False).head(10)

plt.figure(figsize = (12,8))

ax = sns.barplot(x = top10_dados_resultados_inhibitor.values, y = top10_dados_resultados_inhibitor.index)

# Inserção de valores na horizontal - https://stackoverflow.com/questions/49820549/labeling-horizontal-barplot-with-values-in-seaborn
for p in ax.patches:
    width = p.get_width()    
    ax.text(width + 1,       
            p.get_y() + p.get_height() / 2,
            '{:1.0f}'.format(width), 
            ha = 'left',   
            va = 'center')

plt.xlabel("Quantidade MOA", fontsize = 16)
plt.ylabel("Inibidores", fontsize = 16)
plt.title("Top 10 ações MOA Inibidores", fontsize = 20)
plt.show()

# %%
dados_resultados_agonist = dados_resultados.filter(regex = '(?:^|_)agonist(?:$|\W)')
top10_dados_resultados_agonist = dados_resultados_agonist.sum().sort_values(ascending = False).head(10)

plt.figure(figsize = (12,8))
ax = sns.barplot(x = top10_dados_resultados_agonist.values, y = top10_dados_resultados_agonist.index)

# Inserção de valores na horizontal - https://stackoverflow.com/questions/49820549/labeling-horizontal-barplot-with-values-in-seaborn
for p in ax.patches:
    width = p.get_width()    
    ax.text(width + 1,       
            p.get_y() + p.get_height() / 2,
            '{:1.0f}'.format(width), 
            ha = 'left',   
            va = 'center')

plt.xlabel("Quantidade MOA", fontsize = 16)
plt.ylabel("Agonistas", fontsize = 16)
plt.title("Top 10 ações MOA Agonistas", fontsize = 20)
plt.show()

# %%
dados_resultados_antagonist = dados_resultados.filter(regex = '(?:^|_)antagonist(?:$|\W)')
top10_dados_resultados_antagonist = dados_resultados_antagonist.sum().sort_values(ascending = False).head(10)

plt.figure(figsize = (12,8))
ax = sns.barplot(x = top10_dados_resultados_antagonist.values, y = top10_dados_resultados_antagonist.index)

# Inserção de valores na horizontal - https://stackoverflow.com/questions/49820549/labeling-horizontal-barplot-with-values-in-seaborn
for p in ax.patches:
    width = p.get_width()    
    ax.text(width + 1,       
            p.get_y() + p.get_height() / 2,
            '{:1.0f}'.format(width), 
            ha = 'left',   
            va = 'center')

plt.xlabel("Quantidade MOA", fontsize = 16)
plt.ylabel("Antagonistas", fontsize = 16)
plt.title("Top 10 ações MOA Antagonistas", fontsize = 20)

plt.show()

# %%
#dados_resultados_outros = dados_resultados[dados_resultados.columns.drop(list(dados_resultados.filter(regex='(?:^|_)antagonist|agonist|inhibitor(?:$|\W)')))]
dados_resultados_outros = dados_resultados[dados_resultados.columns[dados_resultados.columns.str.contains('inhibitor|agonist', regex=True) == False]]
top10_dados_resultados_outros = dados_resultados_outros.drop(['n_moa', 'id', 'ativo_moa'], axis = 1).sum().sort_values(ascending = False).head(10)

plt.figure(figsize = (12,8))
ax = sns.barplot(x = top10_dados_resultados_outros.values, y = top10_dados_resultados_outros.index)

# Inserção de valores na horizontal - https://stackoverflow.com/questions/49820549/labeling-horizontal-barplot-with-values-in-seaborn
for p in ax.patches:
    width = p.get_width()    
    ax.text(width + 1,       
            p.get_y() + p.get_height() / 2,
            '{:1.0f}'.format(width), 
            ha = 'left',   
            va = 'center')

plt.xlabel("Quantidade MOA", fontsize = 16)
plt.ylabel("Outros Mecanismos", fontsize = 16)
plt.title("Top 10 ações MOA Outros", fontsize = 20)

plt.show()

# %% [markdown]
# **Desafio 02: Criar a coluna eh_controle para quando na linha tratamento == com_controle**

# %%
dados_combinados['eh_controle'] = (dados['tratamento'] == 'com_controle').astype(int)
dados_combinados[['tratamento', 'eh_controle']]
# Out:
#          tratamento  eh_controle
# 0         com_droga            0
# 1         com_droga            0
# 2         com_droga            0
# 3         com_droga            0
# 4         com_droga            0
# ...             ...          ...
# 23809     com_droga            0
# 23810     com_droga            0
# 23811  com_controle            1
# 23812     com_droga            0
# 23813     com_droga            0
#
# [23814 rows x 2 columns]

# %% [markdown]
# **Desafio 03: Criar três colunas para indicar o tempo 24, 48, 72**

# %%
dados_combinados['tempo_24'], dados_combinados['tempo_48'], dados_combinados['tempo_72'] = (dados_combinados['tempo'] == 24).astype(int), (dados_combinados['tempo'] == 48).astype(int), (dados_combinados['tempo'] == 72).astype(int)
dados_combinados.head()[['tempo', 'tempo_24', 'tempo_48', 'tempo_72']]
# Out:
#    tempo  tempo_24  tempo_48  tempo_72
# 0     24         1         0         0
# 1     72         0         0         1
# 2     48         0         1         0
# 3     48         0         1         0
# 4     72         0         0         1

# %% [markdown]
# **Desafio 05: Fazer análise mais detalhada considerando tempo e dose, para comparar as distribuições (Escolher uma droga e comparar com controle)**

# %%
composto = dados_combinados[dados_combinados['composto']=='87d714366']
controle = dados_combinados.query('tratamento == "com_controle"')

fig, axes = plt.subplots(1,2,figsize=(20,8))
sns.boxplot(data=composto, y='g0', x='tempo', hue='dose',ax=axes[0])
axes[0].set_title('Composto 87d714366')

sns.boxplot(data=controle, y='g0', x='tempo', hue='dose',ax=axes[1])
axes[1].set_title('Controle')

fig.suptitle('Análise de g0 com composto ou controle durante o tempo', fontsize = 16)
fig.show()

# %% [markdown]
# Conforme imagem acima, podemos verificar que utilizando o composto 87d714366 possuímos valores diferentes para a nossa expressão gênica 0 quando utilizado apenas o controle.
#
# Com a utilização do composto, verificamos que ocorre uma dispersão dos valores, ficando mais afastados em relação à média, não mantendo a constância durante o tempo igual ao tratamento com controle.

# %% [markdown]
# **Desafio 06: Descobrir se tem algum composto que dependendo da configuração do experimento, ativa ou não ativa algum MOA**

# %% [markdown]
# Conforme comando abaixo, podemos realizar um agrupamento por composto e filtrarmos pela coluna ```n_moa```, retirando o número de valores únicos e realizando uma contagem para todos.
#
# Isso significa que temos 1 valor único para todos os compostos, não sendo alterado pelas configurações (dose, tempo) de nosso experimento.

# %%
dados_combinados.groupby('composto')['n_moa'].nunique().value_counts()
# Out:
# 1    3289
# Name: n_moa, dtype: int64

# %% [markdown]
# Abaixo, realizei o plot dos 15 compostos mais utilizados com diferentes valores de tempo e dose para demonstrar que não ocorre a alteração do número de MOA (Mecanismo de Ação do Alvo - interação entre a droga utilizada e um alvo).

# %%
top15_compostos_droga = dados.query('tratamento == "com_droga"')['composto'].value_counts().index[:15]
top15_compostos_droga

fig = sns.FacetGrid(dados_combinados.query('composto in @top15_compostos_droga'), col="tempo",  row="dose", height=5)
fig.map_dataframe(sns.barplot, y="composto", x = "n_moa", order = top15_compostos_droga, palette = 'mako')

plt.show()

# %% [markdown]
# **Desafio 07: Descobrir se tem algum composto que dependendo da configuração do experimento, ativa MOAs diferentes**
#
# Conforme comando abaixo, podemos realizar um agrupamento por composto e filtrarmos pelas colunas ```colunas_moas```, retirando o número de valores únicos para criar uma tabela de valores únicos.
#
# Após a criação dessa tabela, realizamos novamente a retirada de número de valores únicos, mas dessa vez por linha, comparando assim os valores de um composto com todas as ```colunas_moas```
#
# Isso significa que temos 1 valor único para todos os compostos comparando com as ```colunas_moas```.

# %%
dados_todos_juntos = pd.merge(dados, dados_resultados.loc[:,:'wnt_inhibitor'], on='id')
colunas_moas = dados_resultados.drop(['id', 'n_moa','ativo_moa'], axis = 1).columns
dados_todos_juntos.groupby('composto')[colunas_moas].nunique().nunique(axis = 1).value_counts()
# Out:
# 1    3289
# dtype: int64

# %% [markdown]
# **Desafio 08 : Resumo dos dados**
#
# Com as análises realizadas, conseguimos identificar que os mecanismos de ação mais utilizados são os inibidores, antagonistas, agonistas e bloqueadores (sendo esse último em sua maioria ```calcium_chanel_blocker```.
#
# Uma verificação importante que foi identificada foi que a configuração do nosso experimento com um composto específico (diferente quantidade de dose ou tempo diferente, não ocasionou um diferente valor para o mecanismo de ação. Isso significou que um composto utilizado com D1 ou D2 com tempos de 24, 48 ou 72 tiveram o mesmo valor de mecanismo de ação (ativação ou não).
#
# Muito parecido com a situação acima, identificamos que dependendo da configuração do experimento utilizada com um composto, também não é realizada a ativação de MOAs diferentes.

# %% [markdown]
# # Aula 5

# %% [markdown]
# Olá Cientista!
#
#
# Na última aula nós analisamos separadamente, através de algumas técnicas, os efeitos em cada gene do grupo "com_tratamento" usados.
# Além disso utilizamos o boxplot para nos auxiliar na análise de forma visual tirando algumas conclusões muito interessantes.
#
# Nesta aula, vamos entender e aplicar o Machine Learning. Primeiramente, vamos entender o que o ML significa. Existem muitas definições para o termo, mas aqui, vamos trazer a definição clássica de um renomado e importante cientista da computação, o Arthur Samuel.
#
# ***“Machine learning is the field of study that gives computers the ability to learn without being explicitly programmed” – (definição clássica de Arthur Samuel, cientista da computação, 1959)***
#
# *Tradução livre: "Machine Learning é um campo de estudo que dá aos computadores a habilidade de aprender sem terem sido programados para tal."*
#
# Podemos interpretar a definição de Samuel, da seguinte forma: para que um computador reconheça determinada imagem, não precisamos passar um conjunto de regras, mostrar vários exemplos é suficiente para que o computador classifique suas imagens. Sendo assim, temos dois fatores determinantes neste processo: um conjunto de dados suficientemente grande e um poder computacional elevado. Por isso, até os anos 2000, era bem difícil encontrarmos problemas significantes resolvidos através do Machine Learning. Mas, a partir de 2009, empresas como a Netflix e Amazon, começaram a resolver problemas reais com o processamento dos dados através no ML, isso porque tinham uma infinidade de dados disponíveis e alto poder computacional.
#
# E quais problemas podemos resolver com esse tipo de algoritmo? Existem diversos casos em que podemos aplicá-los mas, vamos subdividir em dois grandes grupos:
#
#     - Problemas em que somos muito bons em resolver mas o Machine Learning, leva essa produção à um nível industrial, como é o caso da classificação de imagens
#     - Problemas em que não somos tão bons em resolver e o Machine Learning pode tomar uma melhor decisão em relação à nossa (imparcialidade, pode ser um fator), como é o caso da concessão de crédito.
#
# Mas como o Machine Learning vai ser aplicado no nosso problema?
# Bom, utilizando a nossa base de dados ```dados_combinados```, o primeiro problema que pensamos em resolver é: **dado os experimentos, queremos saber se qualquer mecanismo de ação foi ativado ou não ativado.** Ou seja, este caso é um problema de classificação binária.
#
# Mas, também podemos pensar se **dado os experimentos, queremos saber se um determinado mecanismo de ação foi ativado, recebendo como resposta, o composto relacionado**. E aqui, temos um problema de classificação multiclasse, já que cada composto químico é considerado uma classe diferente.

# %%
dados_combinados.head()
# Out:
#              id tratamento  tempo  ... tempo_24 tempo_48  tempo_72
# 0  id_000644bb2  com_droga     24  ...        1        0         0
# 1  id_000779bfc  com_droga     72  ...        0        0         1
# 2  id_000a6266a  com_droga     48  ...        0        1         0
# 3  id_0015fd391  com_droga     48  ...        0        1         0
# 4  id_001626bd3  com_droga     72  ...        0        0         1
#
# [5 rows x 883 columns]

# %% [markdown]
# Em nossa base ```dados_resultados``` encontramos o ID do composto e quais mecanismos de ação foram acionados por determinado experimento. Aqui, como um composto pode acionar mais de um mecanismo, nós teremos uma classificação multilabel (quando uma única instância pode ter mais de uma classe associada) e, através de um algoritmo de Machine Learning nós também podemos resolver esse problema : **não somente ter como retorno se um mecanismo de ação foi ativado mas qual ou quais são estes mecanismos**
#
# É importante lembrar que nossas bases de dados estão separadas com um propósito. A segunda ```dados_resultados``` é como se fosse a resposta e foi construída por cientistas que analisaram o efeito de um determinado composto no mais de 700 genes. Esse conhecimento, virou uma base de dados com o passar dos anos e é fruto de análise científica.
#
# E o papel de um modelo de ML neste caso é, a partir de todo esforço humano empenhado por vários anos para entender e tabular qual efeito de um composto quimíco em uma determinada expressão gênica, ser treinado e aprender, ou seja, ser capaz de produzir resultados compatíveis com aqueles feitos pelos(as) próprios(as) cientistas.
#
# Aqui na imersão, vamos começar resolvendo o problema menos complexo, a classificação binária: **dado os experimentos, queremos saber se QUALQUER mecanismo foi ativado ou não.** Basicamente, queremos que o modelo faça predições compátivel com a última coluna da nossa base de dados, a ```ativo_moa```.

# %%
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %% [markdown]
# As etapas lógicas do nosso processo é :
#
#   - Dado um composto -> Temos a Assinatura Celular (```g e c```) -> Analisamos o(s) mecanismo(s) de ação ativados (MoA)
#
# Mas a nossa pergunta a ser respondida é, "**Dado um composto e uma assinatura celular, houve algum MoA ativado?**"
#
# Então, as etapas lógicas passam a ser :
#
#   - Composto -> Assinatura Celular -> MoA ativado?
#
# E como nosso modelo vai aprender a partir da nosa base de dados?
#
#     Composto 1 -> Assinatura A -> MoA = 1
#     Composto 2 -> Assinatura B -> MoA = 0
#     Composto 3 -> Assinatura C -> MoA = 1
#     ...
#     Composto N -> Assinatura N -> MoA = 0
#
# Ou seja, toda a nossa base de dados ```dados_combinados``` será a fonte de aprendizado do nosso modelo. Onde, cada experimento (linha) representa um exemplo (assinatura) e terá como variável resposta (target), a coluna ```ativo_moa```, uma variável binário (0, 1).
#
# E, por fim, o nosso modelo deverá ser capaz de resolver o seguinte problema :
#
#   - Composto candidato -> Assinatura X -> MoA = 1 ou MoA = 0?

# %% [markdown]
# Existem diversas técnicas de Machine Learning (ML) que são capazes de solucionar o nosso problema, mas aqui, iremos utilizar a Regressão Logística e, essa técnica já está implementada em uma biblioteca bastante usada e bem importante para ML no Python, o [Scikit-Learn](https://scikit-learn.org/stable/).
#
# Também estou deixando o link para o nosso subtítulo de interesse [**"1.1.11 Logistic Regression"**](https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression)

# %% [markdown]
# Quando realizamos a implementação de um modelo de classificação, precisamos separar a nossa base de dados em base de treino e base de teste. A base de treino vai ser onde o nosso modelo vai aprender e, a base de teste serve para a verificação do aprendizado do modelo, ou seja, poderemos enteder se as previsões do nosso modelo estão de acordo com o esperado.
#
# Não podemos treinar e testar o modelo com o mesmo conjunto de dados porque, seria muito mais fácil dele prever corretamente.
#
# Para fazer essa divisão, utilizamos a função ```train_teste_split``` do Scikit-Learn (```from sklearn.model_selection import train_test_split```).
#
# Para fazer a divisão da base de dados, é necessário definir qual será o nosso ```x``` e o nosso ```y```, sendo :
#
# - x = Variáveis preditoras (colunas que serão utilizadas para previsão da variável target)
# - y = Variável target (coluna que será prevista através das variáveis preditoras)
#
# Assim, teremos:
#
#     x = dados_combinados.select_dtypes('float64')  ->  toda a base de dados que tem os valores com o formato, ```float64```, no nosso caso, todas as variáveis ```g``` e ```c```
#
#     y = dados_combinados['ativo_moa']  ->  apenas a coluna target, ou seja, ```ativo_moa```
#
# Para o ```train_test_split``` definiremos:
#
#     x_treino, x_teste, y_treino, y_teste
#
# E a função receberá como parâmetro:
#
#     train_test_split(x, y, test_size = 0.2)
#
# Onde,
#
#     x -> base de dados definida como x, no nosso caso, todas as variáveis ```g``` e ```c```
#
#     y -> variável resposta, no nosso caso, ```ativo_moa```
#
#     teste_size = 0.2 -> tamanho que definimos para a base de teste
#
# A proporção entre treino e teste, varia de acordo com o volume de dados que temos. Mas, usualmente, encontramos proporções 30/70, 25/75 ou 20/80. Aqui, definimos como 0,2 ou 20%, isso significa que a base de treino será composta pelos 80% restante.

# %%
from sklearn.model_selection import train_test_split

x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa']

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2)

# %% [markdown]
# Agora, podemos fazer a nossa primeire regressão logística.
#
# Após a definição de nossas variáveis treino e teste, definimos um nome para o nosso modelo (```modelo_rlogistica````) e declaramos a função ```LogisticRegression()```. Acrescenteamos um parâmetro ```max_iter = 1000``` no modelo para que ele seja capaz de convergir para um resultado e assim, não recebemos nenhum warning.
#
# Em seguida, realizamos o treinamento do modelo com o ```.fit(x_treino, y_treino)
#
# E por fim, usamos a função ```.score(x_teste, y_teste) para verificar como o nosso modelo ajustado está se saindo nos dados de teste. O score() calcula a acurácia, ou seja, quantas predições o nosso modelo acertou na base de teste.
#
# Como resultado, temos o valor da acurácia de aproximadamente 0,627. Então, concluímos que o nosso modelo está acertando ~62% das previsões (caso tivéssemos 100 experimentos, o modelo acertaria 62 casos e erraria 38 casos).

# %%
# Modelo criado implementando as colunas 'tempo_24, tempo_48, tempo_72' junto com os 'G's e 'C's para a previsão da variável target 'ativo_moa'

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

x = dados_combinados.drop(['id', 'ativo_moa', 'n_moa', 'tratamento', 'dose', 'composto'], axis=1)
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify = y, random_state = 376)

modelo_rlogistica = LogisticRegression(max_iter = 1000)
modelo_rlogistica.fit(x_treino, y_treino)
modelo_rlogistica.score(x_teste, y_teste)
# Out:
# 0.6663867310518581

# %%
# Modelo criado apenas implementando os G's e C's para a previsão da variável target 'ativo_moa'

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify = y, random_state = 376)

modelo_rlogistica = LogisticRegression(max_iter = 1000)
modelo_rlogistica.fit(x_treino, y_treino)
modelo_rlogistica.score(x_teste, y_teste)
# Out:
# 0.6267058576527399

# %% [markdown]
# Para estabelecer se temos um bom valor de acurácia, precisamos de uma base comparativa, quer dizer, preciso do resultados de um outro modelo para entender se estamos acertando mais ou menos casos.
#
# Para isso, o Scikit-Learn, já tem implementado alguns algoritmos que fazem modelos menos complexos. Neste caso, vamos usar o ```DummyClassifier```.
#
# Ao instanciarmos o ```DummyClassifier```, precisamos definir a estratégia que ele usará para fazer o ajuste do modelo. No nosso caso, definimos a estratégia será os dados mais frequentes, isso quer dizer que: dado o valor mais frequente da nossa variável resposta (```ativo_moa```), o modelo Dummy vai chutar que todos os eventos da base de dados assumem aquele valor no target. Assim, temos: ```DummyClassifier('most_frequent')```.
#
# Nesse momento, para calcular a acurácia, vamos usar outra estratégia, a função ```accuracy_score``` também do Scikit-Learn. Ela receberá como parâmetros a base teste da variável resposta (```y_teste```) e as previsões do modelo que, até o momento ainda não calculamos.
# Para calcular as previsões, usamos o ```.predict()``` da mesma biblioteca que, receberá como parâmetro a base ```x_teste```.
# Por fim, o cálculo da acurácia será:
#
#     previsao_dummy = modelo_dummy.predict(x_teste)
#     accuracy_score(y_teste, previsao_dummy)
#
# A acurácia do ```DummyClassifier```foi de ~60,7%, isso significa que nosso modelo ```LogisticRegression``` teve um desempenho um pouco melhor.

# %%
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score

modelo_dummy = DummyClassifier('most_frequent')
modelo_dummy.fit(x_treino, y_treino)
previsao_dummy = modelo_dummy.predict(x_teste)
accuracy_score(y_teste, previsao_dummy)
# Out:
# 0.6067604450976275

# %% [markdown]
# Podemos entender a acurácia do DummyClassifier se fizermos um value_counts normalizado e então verificamos que a proporção entre a classe 0 e a classe 1 é 60/30, ou seja, o valor mais frequente (estratégia usada no DummyClassifier) representa 60% da base de dados. Isso quer dizer que, caso o modelo chutasse a mesma classe para todos os eventos da base de teste, teríamos um acerto de 60% dos casos.

# %%
dados_combinados['ativo_moa'].value_counts(normalize=True)
# Out:
# True     0.60666
# False    0.39334
# Name: ativo_moa, dtype: float64

# %% [markdown]
# Entretanto, toda vez que rodamos tanto a nossa regressão logística, quanto o nosso dummy classifier, recebemos como retorno um valor diferente de acurácia, apesar de em muitos casos, serem próximos.
#
# O ```train_test_split``` a base de dados em subconjuntos aleatórios de treino e teste. Isso significa que toda vez que você executá-lo, você obterá um resultado diferente.
#
# Por outro lado, se você declarar o parâmetro ```random_state = n```, poderá garantir que a saída de todas as execuções será igual, ou seja, sua divisão será sempre a mesma. Não importa qual número você escolherá para o ```random_state```, o importante é que toda vez que você usá-lo, sempre terá a mesma saída.
#
# Além do ```random_state```, existe mais um parâmetro bem importante que deve ser levado em consideração na divisão da nossa base de dados, o ```stratify```.
#
# Se repararmos na divisão da variável ```ativo_moa```, entre ```true``` e ```false```, percebemos que segue um balanceamento 60/40. E, é do nosso interesse que as bases de treino e teste sigam, além de uma divisão reprodutível (garantida com ```random_state```), a proporção original do conjunto de dados. Assim, atribuimos ```stratify = coluna```, onde ```coluna = nome da coluna que o stratify deve levar em consideração a proporção de classes```. No nosso caso, usamos ```stratify = y```, pois ```y``` é a nossa variável resposta e, é dela que o stratify deve considerar a proporção: 60/40.
#
# Esses parâmetros são úteis, porque garantimos que os resultados são reproduzíveis e compatíveis, independente do modelo (qual técnica, por exemplo, regressão logística, dummy classifier, árvore de decisão e etc) que vamos treinar e testar a partir desta divisão.
#
# Ou seja, ao final, nosso ```train_teste_split``` ficará:
#
#     x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=376)

# %% [markdown]
# Nesse momento, temos interesse a explorar outras técnicas de modelagem para comparar os resultados obtidos e ver qual o melhor algoritmo que conseguimos produzir.
#
# Sendo assim, vamos testar uma nova técnica: a árvore de decisão.
#
# Novamente, a sequência lógica para ajustar esse novo modelo é muito parecida com que estávamos vendo até o momento: definimos as bases ```x``` e ```y```, fazemos o ```train_test_split```, declaramos o novo modelo, ajustamos e verificamos a acurácia.
#
# Aqui, vamos usar o ```DecisionTreeClassifier```, também da biblioteca Scikit-Learn. O único parâmetro que vamos declarar para esta função será o ```max_depth = 3``` mas, vamos explorar seu significado a seguir.
#
# Como resultado, temos uma acurácia (calculada a partir da base de teste) de ~0,61% e, é um pouco menos do que a acurácia obtida com a regressão logística.

# %%
from sklearn.tree import DecisionTreeClassifier

x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa']

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=376)
modelo_arvore = DecisionTreeClassifier(max_depth = 3)
modelo_arvore.fit(x_treino, y_treino)
modelo_arvore.score(x_teste, y_teste)
# Out:
# 0.6105395758975436

# %% [markdown]
# Agora, vamos entender melhor como funciona uma árvore de decisão e o que significa o parâmetro max_depth = 3. Plotamos uma imagem que representa o nosso modelo e, nesse momento, é importante que você não se apegue ao código que usamos para isso. O que realmente é relevante é entender o algoritmo!
#
# A figura é dividida em 4 níveis e, o primeiro nível (estamos considerando a orientação de cima para baixo), é composto por apenas um quadro que é chamado de nó raíz ou somente raíz e ele tem como regras, os melhores atributos que podem dividir a nossa base de dados em dois conjuntos distintos (lembrando que nosso objetivo é separar a nossa base de dados em mecanismo de ação ativado ou não ativado).
#
# Entre o primeiro e o segundo nível (e nos demais níveis), temos duas setas: uma para a direita e outra para a esquerda. Essas setas são chamadas de ramos e subdividem o nível acima em dois outros conjuntos que separam novamente os dados em mecanismo de ação ativado ou não ativado, a partir de uma decisão.
#
# O último nível da árvore (mais abaixo), apresenta n quadros que apresentam características que devem ser levadas em conta na hora da classificação e se dividem em class = ativado e class = não ativado. Esse nível não apresenta mais ramificações e, esses quadros são chamados de folhas.
#
# Se reparmos, a nossa árvore tem 3 níveis de decisão a partir da raíz e é exatamente isso que o parâmetro max_depthrepresenta: a profundidade da árvore.

# %%
from sklearn import tree

fig, ax = plt.subplots(figsize=(15, 10), facecolor='k')
tree.plot_tree(modelo_arvore,
               ax=ax,
               fontsize=10,
               rounded=True,
               filled=True,
               feature_names=x_treino.columns,
               class_names=['Não Ativado', 'Ativado'])

plt.show()

# %% [markdown]
# Como vimos, o desempenho do nosso novo modelo com apenas 3 camadas de decisão não foi tão satisfatório assim. Por isso, vamos variar o ```max_depth``` dentro de um intervalo de valores (range) e comparar os resultados obtidos.
#
# O processo para obter os valores que queremos, é sempre o mesmo. Por isso, vamos criar um loop ou um laço de repetição (um loop, executa um bloco de código em repetição enquanto uma condição é atendida).
#
# Então, após fazermos a separação da base de dados em ```x``` e ```y``` e dividí-las no ```train_test_split```, vamos criar um ```for``` para que nosso modelo seja treinado e testado em repetição dentro de um range. Para isso, faremos:
#
#     teste=[]  ->  criando lista para armazenar os resultados da acurácia nos dados de teste
#     treino=[]  ->  criando lista para armazenar os resultados da acurácia nos dados de treino
#     for i in range(1,15):  ->  estabelecendo condição que deve ser atendida (i) e range de valor (range(1, 15))
#         modelo_arvore = DecisionTreeClassifier(max_depth = i)  ->  instanciando modelo que será treinado e definindo max_depth = i, ou seja, estamos variando a profundidade da nossa árvore
#         modelo_arvore.fit(x_treino, y_treino)  ->  ajustando o modelo a partir das bases de treino
#         teste.append(modelo_arvore.score(x_teste, y_teste))  ->  armazenando os resultados de acurácia de teste dos modelos produzidos na lista 'teste'
#         treino.append(modelo_arvore.score(x_treino, y_treino))  ->  armazenando os resultados de acurácia de treino dos modelos produzidos na lista 'treino'

# %%
from sklearn.tree import DecisionTreeClassifier

x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa'] 
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=376)

teste=[]
treino=[]
for i in range(1,15):
    modelo_arvore = DecisionTreeClassifier(max_depth = i)
    modelo_arvore.fit(x_treino, y_treino)
    teste.append(modelo_arvore.score(x_teste, y_teste))
    treino.append(modelo_arvore.score(x_treino, y_treino))

# %% [markdown]
# Quando chamamos as saídas nosso for(teste e treino), podemos observar um comportamento estranho : enquanto nos dados de teste, o valor da nossa acurácia vai caindo, nos dados de treino, esse valor vai aumentando.

# %%
teste
# Out:
# [0.6067604450976275,
#  0.6067604450976275,
#  0.6105395758975436,
#  0.6206172580306529,
#  0.6204073063195465,
#  0.6183077892084821,
#  0.6208272097417594,
#  0.6210371614528658,
#  0.6166281755196305,
#  0.6132689481419273,
#  0.6099097207642242,
#  0.6019315557421793,
#  0.5985723283644762,
#  0.5962628595423053]

# %%
treino
# Out:
# [0.6066348223190384,
#  0.6066348223190384,
#  0.6211222508004829,
#  0.6360820954280615,
#  0.6412261823526324,
#  0.6489423127394888,
#  0.6605427536612252,
#  0.6707259461445594,
#  0.689570101307018,
#  0.7068395359823632,
#  0.7293055482651829,
#  0.7530838276205973,
#  0.7770195790247231,
#  0.7989606844785051]

# %%
np.argmax(teste) + 1
modelo_arvore = DecisionTreeClassifier(max_depth = np.argmax(teste) + 1)
modelo_arvore.fit(x_treino, y_treino)
modelo_arvore.score(x_teste, y_teste)
# Out:
# 0.6210371614528658

# %% [markdown]
# Para investigar o que aconteceu, vamos plotar um gráfico para entender o comportamento combinado dessas listas.
#
# Usaremos o ```lineplot``` do Seaborn para construir essa visualização.
# Como parâmetros, teremos:
#
#     x = range(1, 15)   ->  intervalo que usamos no for
#     y = teste e y = treino  ->  listas criamos no for e será usada no eixo y do gráfico
#     label = 'teste' e label = 'teste'  ->  etiqueta para identificar as duas linhas que estarão no gráfico
#
# Observando o gráfico produzido, podemos perceber que, inicialmente, os valores de treino e teste são muito próximos mas, conforme vamos aumentando o range, o valor da acurácia para os dados de treino aumentam muito enquanto, esse mesmo valor para os dados de teste, vai caindo (as linhas vão se afastando).
#
# Isso significa que, conforme aumentamos a profundidade da nossa árvore de decisão, a classificação para os dados de treino ficam muito boas pois, ela consegue captar muito bem as características desses dados. Mas, em contrapartida, o modelo fica tão bom os dados de treino que, quando apresentamos um novo conjunto de dados (teste), ele não consegue generalizar tão bem e assim, temos uma acurácia em queda.
#
# Esse problema de um modelo com performance muito boa nos dados de treino mas performance em queda nos dados de teste, é muito conhecido na ciência de dados e chamamos de **overfitting**.
#
# Então, conseguimos perceber que, para melhorar o nosso modelo, não é suficiente somente aumentar a profundidade da árvore de decisão e assim, precisamos traçar uma outra etratégia para melhorar a performance do nosso modelo.
#
# Nesse momento, vamos testar uma nova técnica de modelagem: o Random Forest.
# O que este modelo faz é criar várias árvores de decisões na qual ele considera amostras aleatórias do nosso conjunto total.

# %%
sns.lineplot(x=range(1,15), y = teste, label='teste')
sns.lineplot(x=range(1,15), y = treino, label='treino')

# %% [markdown]
# A função que treina um modelo de Random Forest (RandomForestClassifier()) não aceita que tenhamos variáveis em formato de string. Por isso, precisamos tratar as variáveis que são strings e transformá-las em números (ou no formato float64).
#
# Para fazer essa transformação, vamos usar uma função do Pandas, chamada get_dummies e nela, declaramos a coluna que queremos que seja transformada. Por exemplo, aqui, usamos:
#
# pd.get_dummies(dados_combinados['tratamento'])
#
# Isso porque, nossa intenção é transformar a coluna ```tratamento``` da base ```dados_combinados``` em dados numéricos.
#
# Para fazer a transformação desejada, o ```get_dummies``` pega todas as categorias de uma variável e as transforma em novas colunas binárias.
# Por exemplo:
#
# A variável ```tratamento``` apresenta duas categorias ```com_controle``` e ```sem_controle```. Quando aplicamos o ```get_dummies```, ele cria duas novas colunas binárias e análogas as categorias.
# Se temos um evento que apresentava na coluna original a marcação ```com_droga```, agora ela apresentará valor 0 na coluna ```com_controle``` e valor 1 na coluna ```com_droga``` e vice-versa.

# %%
pd.get_dummies(dados_combinados[['tratamento', 'dose', 'tempo']])
# Out:
#        tempo  tratamento_com_controle  tratamento_com_droga  dose_D1  dose_D2
# 0         24                        0                     1        1        0
# 1         72                        0                     1        1        0
# 2         48                        0                     1        1        0
# 3         48                        0                     1        1        0
# 4         72                        0                     1        0        1
# ...      ...                      ...                   ...      ...      ...
# 23809     24                        0                     1        0        1
# 23810     24                        0                     1        0        1
# 23811     48                        1                     0        0        1
# 23812     24                        0                     1        1        0
# 23813     72                        0                     1        1        0
#
# [23814 rows x 5 columns]

# %% [markdown]
# Aqui, estamos estabelecendo qual será a base de dados usada para modelar o novo algoritmo. Agora, não mais consideraremos apenas os dados genéticos, também levaremos em conta as demais variáveis, exceto as seguintes variáveis:
#
#     'id'  ->  não será relevante nesse momento pois é somente um número de identificação
#     'n_moa'  ->  não será relevante nesse momento pois é a quantidade de MoAs ativados
#     'ativo_moa'  ->  retiramos da base pois é a nossa variável resposta
#     'composto'  ->  não será relevante nesse momento pois identifica o composto usado e foge do que estamos buscando fazer
#
# Para retirar essas variáveis da nossa base de dados, usamos a função ```drop```, declaramos as variáveis a serem retiradas em forma de uma lista e identificamos que são colunas através do parâmetro ```axis = 1```.

# %%
dados_combinados.drop(['id', 'n_moa', 'ativo_moa', 'composto'], axis = 1)
# Out:
#          tratamento  tempo dose  ...  tempo_24  tempo_48  tempo_72
# 0         com_droga     24   D1  ...         1         0         0
# 1         com_droga     72   D1  ...         0         0         1
# 2         com_droga     48   D1  ...         0         1         0
# 3         com_droga     48   D1  ...         0         1         0
# 4         com_droga     72   D2  ...         0         0         1
# ...             ...    ...  ...  ...       ...       ...       ...
# 23809     com_droga     24   D2  ...         1         0         0
# 23810     com_droga     24   D2  ...         1         0         0
# 23811  com_controle     48   D2  ...         0         1         0
# 23812     com_droga     24   D1  ...         1         0         0
# 23813     com_droga     72   D1  ...         0         0         1
#
# [23814 rows x 879 columns]

# %% [markdown]
# Enfim, podemos partir para o ajuste do nosso modelo de Random Forest.
#
# Novamente, vamos seguir as mesmas etapas lógicas anteriores. Entretando, precisamos modificar o a nossa base ```x```.
# Então faremos:
#
#     x = dados_combinados.drop(['id', 'n_moa', 'ativo_moa', 'composto'], axis=1)  ->  base de dados de deve ser considerada com a exclusão das colunas que determinamos anteriormente
#     x = pd.get_dummies(x, columns=['tratamento', 'dose', 'tempo'])  ->  a partir do x definido acima, fazemos a transformação com o get_dummies nas colunas com o formato de string
#
# Por fim, temos como retorno uma acurácia de ~68,0% e, ela é, aproximadamente, 7% melhor que a acurácia que conseguimos com o ```DummyClassifier```. Aqui, não podemos comparar com a regressão logística porque estamos considerando um outro conjunto de dados.
#
# É muito importante ressaltar que, apesar de termos melhorado a acurácia do nosso modelo, pensando na vida real, talvez a nossa melhora ainda não seja suficiente. Ou seja, desenvolvemos um modelo com um algoritmo de Machine Learning mas, ele ainda não é aplicável à vida real (isso quer dizer que, ainda não nos traz ganhos suficientes para sua implantação).
#
# Por outro lado, durante todo o nosso projeto, desenvolvemos modelos simples e não nos aprofundamos em todos os pontos que podem ser modificados (variáveis, parâmetros de modelos, por exemplo) a fim de otimizar a nossa generalização.
# Deixamos em destaque também a sua trajetória até aqui, certamente ela deve ser seu foco (e é também o nosso)! O resultado é apenas uma consequência disso tudo e sabemos que, para melhorá-lo você precisa persistir no estudo dessa área.
#
# A Imersão de Dados 3 foi o seu primeiro passo na ciência de dados e aqui, deixamos o convite para que você continue estudando, explorando e aprendendo todos os processos e áreas desse mundo gigantesco de possibilidades!
#
# Nos vemos em breve, cientistas!

# %%
from sklearn.ensemble import RandomForestClassifier

x = dados_combinados.drop(['id', 'n_moa', 'ativo_moa', 'composto'], axis = 1)
x = pd.get_dummies(x, columns = ['tratamento', 'dose', 'tempo'])
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=376)

modelo_randomforest = RandomForestClassifier()
modelo_randomforest.fit(x_treino, y_treino)
modelo_randomforest.score(x_teste, y_teste)
# Out:
# 0.6854923367625446

# %%
 max_values_30_idx = pd.Series(modelo_randomforest.feature_importances_).sort_values(ascending = False)[:30].index

plt.figure(figsize = (14,8))

ax = sns.barplot( x = modelo_randomforest.feature_importances_[max_values_10_idx] , y = x.columns[max_values_30_idx])

plt.title('Top 10 Variáveis Importantes do Modelo', fontsize = 18)
plt.ylabel('Variáveis', fontsize = 15)
plt.xlabel('Valor Importância', fontsize = 15)
# Out:
# Text(0.5, 0, 'Valor Importância')

# %%
from sklearn.ensemble import RandomForestClassifier

x = dados_combinados.drop(['id', 'n_moa', 'ativo_moa', 'composto', 'tempo_24', 'tempo_48', 'tempo_72'], axis = 1)
x = pd.get_dummies(x, columns = ['tratamento', 'dose', 'tempo'])
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=376)

modelo_randomforest = RandomForestClassifier()
modelo_randomforest.fit(x_treino, y_treino)
modelo_randomforest.score(x_teste, y_teste)

# %% [markdown]
# **Desafio 01: Tente outros modelos ou mude os parâmetros dos modelos que testamos em aula.**

# %%
# Utilizando um classificador Naive Bayes

from sklearn.naive_bayes import GaussianNB

x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa'] 
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, random_state=376)

modelo_v1 = GaussianNB()
modelo_v1.fit(x_treino, y_treino.ravel())
print(f'Resultado Naive Bayes : {modelo_v1.score(x_teste, y_teste)}')

# %%
# Utilizando o método SGD Classifier
from sklearn.linear_model import SGDClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

x = dados_combinados.drop(['id', 'n_moa', 'ativo_moa', 'composto', 'tratamento'], axis=1)
x = pd.get_dummies(x, columns = ['dose', 'tempo'])
y = dados_combinados['ativo_moa']

modelo_SGD = make_pipeline(StandardScaler(), SGDClassifier(max_iter=1000, tol=1e-3), verbose=True)
modelo_SGD.fit(x, y)
modelo_SGD.score(x, y)

# %%
# Removendo as variáveis 'tempo_24', 'tempo_48', 'tempo_72'

from sklearn.ensemble import RandomForestClassifier

x = dados_combinados.drop(['id', 'n_moa', 'ativo_moa', 'composto', 'tempo_24', 'tempo_48', 'tempo_72'], axis = 1)
x = pd.get_dummies(x, columns = ['tratamento', 'dose', 'tempo'])
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=376)

modelo_randomforest = RandomForestClassifier()
modelo_randomforest.fit(x_treino, y_treino)
modelo_randomforest.score(x_teste, y_teste)

# %%
# Removendo a variável 'tempo'
from sklearn.ensemble import RandomForestClassifier

x = dados_combinados.drop(['id', 'n_moa', 'ativo_moa', 'composto', 'tempo'], axis = 1)
x = pd.get_dummies(x, columns = ['tratamento', 'dose'])
y = dados_combinados['ativo_moa']
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=376)

modelo_randomforest = RandomForestClassifier()
modelo_randomforest.fit(x_treino, y_treino)
modelo_randomforest.score(x_teste, y_teste)
